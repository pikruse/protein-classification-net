# %%
import requests
import os
import shutil
import numpy as np
import math
import glob

def fetch_pdb(pdb_id):
    """
    Fetches a PDB file from the RCSB database.
    Args:
        pdb_id (str): The PDB ID of the structure.
    Returns:
        str: The raw PDB file data.
    """
    url = f"https://files.rcsb.org/download/{pdb_id.upper()}.pdb"
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        raise Exception(f"Failed to fetch PDB file for {pdb_id}. HTTP Status: {response.status_code}")

def pdb_to_xyz(pdb_data, pdb_id):
    """
    Converts PDB data to XYZ format, adding the PDB ID as the second line.
    Args:
        pdb_data (str): The raw PDB file data.
        pdb_id (str): The PDB ID to be added as the second line in the XYZ file.
    Returns:
        str: XYZ formatted string.
    """
    xyz_lines = []
    with open (pdb_data, "r") as file:
        for line in file:
            if line.startswith("ATOM") or line.startswith("HETATM"):
                atom_name = line[12:16].strip()
                element = line[76:78].strip()
                x = line[30:38].strip()  # Original precision X
                y = line[38:46].strip()  # Original precision Y
                z = line[46:54].strip()  # Original precision Z

                # Clean up atomic information and use full precision from the PDB file
                xyz_line = f"{element} {x} {y} {z}"
                xyz_lines.append(xyz_line)

        # Write the number of atoms followed by the PDB ID and atom lines
        xyz_output = f"{len(xyz_lines)}\n"
        xyz_output += f"{pdb_id.upper()}\n"  # PDB ID as the second line
        xyz_output += "\n".join(xyz_lines)
    return xyz_output

def save_xyz(output_dir, pdb_id, xyz_data):
    """
    Saves the XYZ data to a file in the given output directory.
    Args:
        output_dir (str): The directory where the output XYZ file should be saved.
        pdb_id (str): The PDB ID to be used in the file name.
        xyz_data (str): The XYZ formatted string.
    """
    os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist
    output_filename = os.path.join(output_dir, f"{pdb_id.upper()}.xyz")
    with open(output_filename, 'w') as file:
        file.write(xyz_data)
    print(f"XYZ data saved to {output_filename}")

#def main(pdb_id, output_dir):
#    pdb_data = fetch_pdb(pdb_id)
#    xyz_data = pdb_to_xyz(pdb_data, pdb_id)
#    save_xyz(output_dir, pdb_id, xyz_data)


#pdb_id = "1n11"  # Example: "1TUP"
#output_dir = "/Users/ntw/Desktop/MHT_Calculations/" +pdb_id
#main(pdb_id, output_dir)

# %%
def parse_xyz(xyz_filename):
    """
    Parses an XYZ file and returns atom data along with indices of BR and CL atoms.
    Args:
        xyz_filename (str): The name of the XYZ file.
    Returns:
        list: List of all atoms with element names and coordinates.
        list: Indices of BR atoms.
        list: Indices of CL atoms.
    """
    atoms = []
    br_atoms = []
    cl_atoms = []

    with open(xyz_filename, 'r') as file:
        lines = file.readlines()[2:]  # Skip the first two lines (atom count and PDB ID)
        
        for i, line in enumerate(lines):
            parts = line.split()
            element = parts[0]
            x, y, z = parts[1], parts[2], parts[3]

            # Add atom data to list
            atoms.append((element, x, y, z))

            # Keep track of BR and CL atom indices
            if element == "Br":
                br_atoms.append(i)
            elif element == "BR":
                br_atoms.append(i)
            elif element == "Cl":
                cl_atoms.append(i)
            elif element == "CL":
                cl_atoms.append(i)

    return atoms, br_atoms, cl_atoms

def swap_elements(atoms, br_idx, cl_idx):
    """
    Swaps a single BR atom with a single CL atom in the atom list.
    Args:
        atoms (list): List of atoms (element, x, y, z).
        br_idx (int): Index of the BR atom to swap.
        cl_idx (int): Index of the CL atom to swap.
    Returns:
        list: A new list of atoms with the BR and CL swapped.
    """
    swapped_atoms = atoms[:]

    # Swap BR with CL at the specified indices
    br_atom = swapped_atoms[br_idx]
    cl_atom = swapped_atoms[cl_idx]

    # Swap their elements
    swapped_atoms[br_idx] = ("Cl", br_atom[1], br_atom[2], br_atom[3])
    swapped_atoms[cl_idx] = ("Br", cl_atom[1], cl_atom[2], cl_atom[3])

    return swapped_atoms

def write_xyz(filename, atoms):
    """
    Writes the list of atoms to an XYZ file.
    Args:
        filename (str): The name of the output XYZ file.
        atoms (list): List of atoms (element, x, y, z).
    """
    with open(filename, 'w') as file:
        file.write(f"{len(atoms)}\n\n")  # First line: number of atoms
        for atom in atoms:
            file.write(f"{atom[0]} {atom[1]} {atom[2]} {atom[3]}\n")


def generate_swapped_files(xyz_filename, output_dir):
    """
    Generates new XYZ files with each BR-CL swap in a separate file.
    Args:
        xyz_filename (str): The input XYZ filename.
        output_dir (str): The directory where the new XYZ files will be saved.
    """
    # Parse the original XYZ file
    atoms, br_atoms, cl_atoms = parse_xyz(xyz_filename)

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Generate all swaps (one BR with one CL)
    for br_idx in br_atoms:
        for cl_idx in cl_atoms:
            # Swap the BR and CL atoms at these indices
            swapped_atoms = swap_elements(atoms, br_idx, cl_idx)

            # Generate a unique output filename for each swap
            output_filename = os.path.join(output_dir, f"swapped_{br_idx}_{cl_idx}_{os.path.basename(xyz_filename)}")
            write_xyz(output_filename, swapped_atoms)
            print(f"Swapped XYZ data saved to {output_filename}")

#def main():
#    xyz_filename = "/Users/ntw/Desktop/MHT_Calculations/1N11/1n11.xyz"
#    output_dir = "/Users/ntw/Desktop/MHT_Calculations/1N11/"
#    generate_swapped_files(xyz_filename, output_dir)
#
#if __name__ == "__main__":
#    main()

# %%
def process_directory(dir_path):
    """
    Method to process a directory.
    Replace this with your desired logic.
    """
    print(f"Processing directory: {dir_path}")

def traverse_directories(root_dir):
    """
    Traverses the directory tree starting from root_dir and 
    applies the process_directory method to each directory.
    """
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for subdirname in dirnames:
            subdir_path = os.path.join(dirpath, subdirname)
            try:
                make_DFTB_input(subdir_path)
            except Exception as e:
                print("Skipping " + subdir_path)
                pass
#traverse_directories("/Users/ntw/Desktop/MHT_Calculations/")

# %%
def filter_xyz(xyz_filename):
    """
    Parses an XYZ file and returns atom data (without BR and CL atoms).
    Args:
        xyz_filename (str): The name of the XYZ file.
    Returns:
        list: List of atoms (element, x, y, z) excluding BR and CL.
    """
    atoms = []

    with open(xyz_filename, 'r') as file:
        lines = file.readlines()[2:]  # Skip the first two lines (atom count and PDB ID)

        for line in lines:
            parts = line.split()
            element = parts[0]

            # If the element is BR or CL, skip this atom
            if element not in ["BR", "CL"]:
                x, y, z = parts[1], parts[2], parts[3]
                atoms.append((element, x, y, z))

    return atoms

def write_filtered_xyz(filename, atoms):
    """
    Writes the list of atoms to an XYZ file.
    Args:
        filename (str): The name of the output XYZ file.
        atoms (list): List of atoms (element, x, y, z).
    """
    with open(filename, 'w') as file:
        file.write(f"{len(atoms)}\n\n")  # First line: number of atoms
        for atom in atoms:
            file.write(f"{atom[0]} {atom[1]} {atom[2]} {atom[3]}\n")

def remove_br_cl_atoms(xyz_filename, output_dir):
    """
    Removes all BR and CL atoms from the XYZ file and saves the result to a new file.
    Args:
        xyz_filename (str): The input XYZ filename.
        output_dir (str): The directory where the new XYZ file will be saved.
    """
    # Parse the original XYZ file, excluding BR and CL atoms
    atoms = filter_xyz(xyz_filename)

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Write the filtered atoms to a new XYZ file
    output_filename = os.path.join(output_dir, f"no_BR_CL_{os.path.basename(xyz_filename)}")
    write_filtered_xyz(output_filename, atoms)
    print(f"Filtered XYZ data saved to {output_filename}")

#def main():
#    xyz_filename = "/Users/ntw/Desktop/MHT_Calculations/1N11/1n11.xyz"
#    output_dir = "/Users/ntw/Desktop/MHT_Calculations/1N11/"
#    remove_br_cl_atoms(xyz_filename, output_dir)
#
#if __name__ == "__main__":
#    main()

# %%
def move_files_to_subdirectories(directory):
    """Moves each file in a directory to its own subdirectory named after the file.

    Args:
        directory: The path to the directory containing the files.
    """
    for filename in os.listdir(directory):
        source_path = os.path.join(directory, filename)
        if ".xyz" in filename:
            if os.path.isfile(source_path):
                file_base_name, _ = os.path.splitext(filename)
                destination_dir = os.path.join(directory, file_base_name)
                os.makedirs(destination_dir, exist_ok=True)
                destination_path = os.path.join(destination_dir, filename)
                shutil.move(source_path, destination_path)
        else: 
            pass

# Example usage:
#directory_path = "/path/to/your/directory"  # Replace with the actual path to your directory
#move_files_to_subdirectories(directory_path)

# %%
def make_ChimeraX_Scripts(parent_directory):
    # Define the parent directory you want to search through

    # Create the run_all.py script in the parent directory
    run_all_script_path = parent_directory + 'run_all.py'

    with open(run_all_script_path, 'w') as f:
        # Write the import statement at the beginning of the script
        f.write("from chimerax.core.commands import run\n\n")
        
        # Iterate through all subdirectories and files in the parent directory
        for filename in glob.glob(os.path.join(parent_directory, "*.pdb")):
            full_pdb_path = os.path.join(parent_directory, filename)
            print(full_pdb_path)
                
                # Define the new filename for the PDB file with "_added_h" added before the .pdb extension
            new_pdb_path = os.path.splitext(full_pdb_path)[0] + '_added_h.pdb'
                
                # Add the commands to the run_all.py script
            f.write(f"open {full_pdb_path}\n")
            f.write(f"addh\n")
            f.write(f"save \"{new_pdb_path}\"\n")
            f.write(f"close all\n")
        
    print(f"Created {run_all_script_path} to process all PDB files!")
    return None

# %%
# Function to calculate the Euclidean distance between two points in 3D space
def calculate_distance(atom1, atom2):
    return math.sqrt((atom1[0] - atom2[0]) ** 2 + (atom1[1] - atom2[1]) ** 2 + (atom1[2] - atom2[2]) ** 2)

# Function to read .xyz file and check for atoms closer than 0.3 Ångströms
def check_atoms_closer_than_threshold(file_path, threshold=0.3):
    with open(file_path, 'r') as file:
        # Read the number of atoms and skip the comment line
        num_atoms = int(file.readline().strip())
        file.readline()
        
        atoms = []
        
        # Read the atoms and their coordinates
        for line in file:
            parts = line.split()
            atom_type = parts[0]
            x, y, z = float(parts[1]), float(parts[2]), float(parts[3])
            atoms.append((atom_type, x, y, z))
        
        # Check distances between all pairs of atoms
        for i in range(len(atoms)):
            for j in range(i + 1, len(atoms)):
                distance = calculate_distance(atoms[i][1:], atoms[j][1:])
                if distance < threshold:
                    print(f"Atoms {atoms[i][0]} at {atoms[i][1:]} and {atoms[j][0]} at {atoms[j][1:]} are {distance:.4f} Ångströms apart")

# Usage example
#check_atoms_closer_than_threshold('/Users/ntw/Desktop/MHT_Calculations/1K63/1K63/1K63.xyz')


# Function to read an XYZ file
def read_xyz(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    num_atoms = int(lines[0].strip())
    atoms = []
    for line in lines[2:]:
        parts = line.split()
        atoms.append([parts[0], float(parts[1]), float(parts[2]), float(parts[3])])
    return atoms

# Function to write an XYZ file


# Function to calculate the distance between two atoms
def calculate_Euclid_distance(atom1, atom2):
    return np.sqrt((atom1[1] - atom2[1])**2 + (atom1[2] - atom2[2])**2 + (atom1[3] - atom2[3])**2)

# Function to process the atoms and remove those that are too close
def remove_close_atoms(atoms, threshold=0.2):
    indices_to_remove = set()
    
    # Check each pair of atoms
    for i in range(len(atoms)):
        for j in range(i+1, len(atoms)):
            distance = calculate_Euclid_distance(atoms[i], atoms[j])
            if distance < threshold:
                # Mark the atom with the higher index for removal
                indices_to_remove.add(j)
    
    # Remove atoms that are too close
    filtered_atoms = [atom for i, atom in enumerate(atoms) if i not in indices_to_remove]
    
    return filtered_atoms

# Main function
def process_xyz(input_filename, output_filename, threshold=0.3):
    atoms = read_xyz(input_filename)
    filtered_atoms = remove_close_atoms(atoms, threshold)
    write_xyz(output_filename, filtered_atoms)

# Example usage
#process_xyz("/Users/ntw/Desktop/MHT_Calculations/1K63/1K63/1K63.xyz", \
#"/Users/ntw/Desktop/MHT_Calculations/1K63/1K63/1K63_corrected.xyz")
#check_atoms_closer_than_threshold('/Users/ntw/Desktop/MHT_Calculations/1K63/1K63/1K63.xyz')

import os
def traverse_check_distance(root_dir):
    """
    Traverses the directory tree starting from root_dir and 
    applies the process_directory method to each directory.
    """
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for subdirname in dirnames:
            subdir_path = os.path.join(dirpath, subdirname)
            try:
                print(subdir_path+"/"+os.path.basename(subdirname)+"/"+os.path.basename(subdirname)+".xyz")
                check_atoms_closer_than_threshold(subdir_path+"/"+os.path.basename(subdirname)+"/"+os.path.basename(subdirname)+".xyz")
            except Exception as e:
                print("Skipping " + subdir_path)
                pass
#traverse_check_distance("/Users/ntw/Desktop/MHT_Calculations/")

# %%
def make_DFTB_input(foldername):
        OUTPUT_FILENAME = 'dftb_in.hsd'
    
        folder = foldername
    
        if not folder:
            print('Cancelled - No valid folder entered')
            return
        try:
            geometryinput = [f for f in os.listdir(folder) if f.endswith('.xyz') or f.endswith('.gen')]
        except:
            print('Cancelled - No .xyz or .gen geometry file found.')
            return
    # =============================================================================
    #     Driver = sg.Window('Driver', [[sg.T('Use conjugate gradient driver for geometry optimization?')], [sg.Yes(s=10), sg.No(s=10)]], disable_close=True).read(close=True)
    #     LevelofTheory = sg.Window('Level of Theory', [[sg.T('Use DFTB3 level of theory?')], [sg.Yes(s=10), sg.No(s=10)]], disable_close=True).read(close=True)
    #     SKfolder = sg.popup_get_folder('Folder for Slater-Koster files.',
    #                               title='DFTB+ GUI')
    # =============================================================================
    
        outfile = open(os.path.join(foldername, OUTPUT_FILENAME), 'w')
    
    #Read and write the geometry file to dftb_in.hsd
        containsSulfur = 0
        containsOxygen = 0
        containsCarbon = 0
        containsChlorine = 0
        containsHydrogen = 0
        containsNitrogen = 0
        containsPhosphorus = 0
        containsBromine = 0
        containsMagnesium = 0
        containsZinc = 0
        input_as_list=[]
        for i, file in enumerate(geometryinput):
            with open(os.path.join(folder, file), "r") as input:
                if file.endswith('.gen'):
                    outfile.write('Geometry=GenFormat{')
                if file.endswith('.xyz'):
                    outfile.write('Geometry=xyzFormat{ \n')
                    for line in input:
                        input_as_list.append(line)
                        outfile.write(line)
                    secondlineonwards=input_as_list[2:]
                #for line in secondlineonwards:
                #        outfile.write(line)
                              
        if 'S' in str(secondlineonwards):
            containsSulfur=1
            print('Input file contains Sulfur')
        if 'C' in str(secondlineonwards):
            containsCarbon=1
            print('Input file contains Carbon')
        if 'H' in str(secondlineonwards):
            containsHydrogen=1
            print('Input file contains Hydrogen')
        if 'O' in str(secondlineonwards):
            containsOxygen=1
            print('Input file contains Oxygen')
        if 'N' in str(secondlineonwards):
            containsNitrogen=1
            print('Input file contains Nitrogen')
        if 'Cl' in str(secondlineonwards):
            containsChlorine=1
        if 'CL' in str(secondlineonwards):
            containsChlorine=1
            print('Input file contains Chlorine')
        if 'P' in str(secondlineonwards):
            containsPhosphorus=1
            print('Input file contains Phosphorus')
        if 'Br' in str(secondlineonwards):
            containsBromine=1
            print('Input file contains Bromine')
        if 'BR' in str(secondlineonwards):
            containsBromine=1
            print('Input file contains Bromine')
        if 'Mg' in str(secondlineonwards):
            containsMagnesium=1
            print('Input file contains Magnesium')
        if 'MG' in str(secondlineonwards):
            containsMagnesium=1
            print('Input file contains Magnesium')        
        if 'Zn' in str(secondlineonwards):
            containsZinc=1
            print('Input file contains Zinc') 
        if 'ZN' in str(secondlineonwards):
            containsZinc=1
            print('Input file contains Zinc')    
                            
    #        outfile.write('}')
    #       if Driver == "('Yes', {})": 
    #           outfile.write("Driver = ConjugateGradient {\n", "MovedAtoms = 1:-1\n", "MaxSteps = -1\n", 'OutputPrefix = "geom.out"/n', '}')
    #       if Driver == "('No', {})":
    #           outfile.write("Driver = GradientDescent {\n", "MovedAtoms = 1:-1\n", "MaxSteps = -1\n", 'OutputPrefix = "geom.out"/n', '}')
        outfile.write('}\n')  
        outfile.write(
    'Hamiltonian = DFTB { \n'
    ' Scc = Yes \n'
    ' MaxSCCIterations = 2000 \n'
    ' SlaterKosterFiles = Type2FileNames { \n'
    '  Prefix = "/home/ntw/TDW_123_MHT_Calculations/MHT_Calculations/3ob-main/skfiles/\n'
    '  Separator = "-" \n'
    '  Suffix = ".skf" \n'
    '  LowerCaseTypeName = No \n'
    '  } \n')
        outfile.write('\n')
        outfile.write(' MaxAngularMomentum { \n')
        if containsCarbon == 1:
                outfile.write('  C = "p" \n')
        if containsHydrogen == 1:
                outfile.write('  H = "s" \n')
        if containsOxygen == 1:
                outfile.write('  O = "p" \n')
        if containsNitrogen == 1:
                outfile.write('  N = "p" \n')
        if containsPhosphorus == 1:
                outfile.write('  P = "d"/n')
        if containsSulfur == 1:
                outfile.write('  S = "d" \n')
        if containsChlorine == 1:
                outfile.write('  Cl = "d" \n')
        if containsBromine == 1:
                outfile.write('  Br = "d" \n')
        if containsMagnesium == 1:
                outfile.write('  Mg = "p" \n')
        if containsZinc == 1:
                outfile.write('  Zn = "d" \n')
        outfile.write('  }')
        outfile.write('\n')
        outfile.write(' ThirdOrderFull=Yes \n HubbardDerivs { \n')
        if containsCarbon == 1:
                outfile.write('  C = -0.1492 \n')
        if containsHydrogen==1:
                outfile.write('  H = -0.1857 \n')
        if containsOxygen==1:
                outfile.write('  O = -0.1575 \n')
        if containsNitrogen==1:
                outfile.write('  N = -0.1535 \n')
        if containsPhosphorus==1:
                outfile.write('  P = -0.14/n')
        if containsSulfur==1:
                outfile.write('  S = -0.11 \n')
        if containsChlorine==1:
                outfile.write('  Cl = -0.0697 \n')
        if containsBromine==1:
                outfile.write('  Br = -0.0573 \n')
        if containsMagnesium==1:
                outfile.write('  Mg = -0.02 \n')
        if containsZinc==1:
                outfile.write('  Zn = -0.03 \n')
        outfile.write('  }')
        outfile.write('\n')
        outfile.write(' HCorrection = Damping {\n     Exponent = 4.00 \n     }')
        outfile.write('\n')
        outfile.write(' Dispersion = DftD3 { \n')
        outfile.write('   Damping = BeckeJohnson { \n')
        outfile.write('     a1 = 0.5719 \n')
        outfile.write('     a2 = 3.6017 \n')
        outfile.write('     } \n')
        outfile.write('  s6 = 1.0  \n')
        outfile.write('  s8 = 0.5883 \n')
        outfile.write('  } \n')
        outfile.write('\n')
        outfile.write(' Solvation = Cosmo {\n')
        outfile.write('    Solvent = FromConstants {\n')
        outfile.write('        Epsilon = 80.2\n')
        outfile.write('        MolecularMass [amu] = 18.0\n')
        outfile.write('        Density [kg/l] = 1.0\n')
        outfile.write('    }\n')
        outfile.write('    FreeEnergyShift [kcal/mol] = 0.0\n')
        outfile.write('    Radii = VanDerWaalsRadiiD3 {}\n')
        outfile.write('    RadiiScaling = 1.55\n')
        outfile.write('    AngularGrid = 110\n')
        outfile.write('    Solver = DomainDecomposition {\n')
        outfile.write('        MaxMoment = 10\n')
        outfile.write('        Accuracy = 1e-8\n')
        outfile.write('        Regularisation = 0.2\n')
        outfile.write('    }\n')
        outfile.write(' }\n')
        outfile.write('\n')
        outfile.write(' Charge = 0 \n')
        outfile.write('} \n')
        outfile.write('Options{} \n')
        outfile.write('Analysis{} \n')
        outfile.write('ParserOptions{} \n')
        outfile.close()
        print('Complete!', 'Generated an input file')

        main()

# %%
def read_file_to_list(file_path):
    """Reads lines from a file and returns them as a list.

    Args:
        file_path: The path to the file.

    Returns:
        A list of strings, where each string is a line from the file.
        Returns an empty list if the file does not exist or is empty.
    """
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            # Remove trailing newlines from each line
            lines = [line.rstrip('\n') for line in lines]
            return lines
    except FileNotFoundError:
        print(f"Error: File not found at path: {file_path}")
        return []

# %%
protein_list = []
protein_input='/Users/ntw/Desktop/MHT_Calculations/Protein_list.txt'
protein_list=read_file_to_list(protein_input)

for i in range(len(protein_list)):
    pdb_id = protein_list[i]
    pdb_file = pdb_id +".xyz"
    base_directory= "/Users/ntw/Desktop/MHT_Calculations/"
    output_dir = base_directory +pdb_id
    pdb_data = fetch_pdb(pdb_id)
    with open (output_dir+".pdb", "w") as file:
        file.write(pdb_data)
    #Add required hydrogens
make_ChimeraX_Scripts(base_directory)
    
    
    
    #xyz_data = pdb_to_xyz(pdb_data, pdb_id)
    #save_xyz(output_dir, pdb_id, xyz_data)
    #Now, check for duplicated atoms
    #input_filename = os.path.join(output_dir, f"{pdb_id.upper()}.xyz")
    #output_filename = os.path.join(output_dir, f"{pdb_id.upper()}_corrected.xyz")
    #process_xyz(input_filename, output_filename)
    #Add required hydrogens
    
    
    
    #xyz_filename = output_dir + "/" + pdb_id + "_corrected.xyz"
    #generate_swapped_files(xyz_filename, output_dir)
    #remove_br_cl_atoms(xyz_filename, output_dir)
    #move_files_to_subdirectories(output_dir)



#for i in range(len(protein_list)):
#    pdb_id = protein_list[i]  # Example: "1TUP"
#    pdb_file = pdb_id +".xyz"
#    output_dir = "/Users/ntw/Desktop/MHT_Calculations/" +pdb_id
#    pdb_data = fetch_pdb(pdb_id)
#    xyz_data = pdb_to_xyz(output_dir+pdb_file, pdb_id)
#    xyz_data = pdb_to_xyz(output_dir+"/full_pdb_added_h.pdb", pdb_id)
#    #print(xyz_data)
#    print(output_dir+"/full_pdb_added_h.pdb")
#    save_xyz(output_dir, pdb_id, xyz_data)
#    xyz_filename = output_dir + "/" +pdb_file
#    print(xyz_filename)
#    generate_swapped_files(xyz_filename, output_dir)
#    remove_br_cl_atoms(xyz_filename, output_dir)
#    move_files_to_subdirectories(output_dir)
    #with open(output_dir+ "/full_pdb.pdb", 'w') as file:
        #file.write(pdb_data)  # First line: number of atoms
    #make_ChimeraX_Scripts("/Users/ntw/Desktop/MHT_Calculations/")
# Out:
# /Users/ntw/Desktop/MHT_Calculations/2VQT.pdb
# /Users/ntw/Desktop/MHT_Calculations/3GW6.pdb
# /Users/ntw/Desktop/MHT_Calculations/5LXR.pdb
# /Users/ntw/Desktop/MHT_Calculations/6RO3.pdb
# /Users/ntw/Desktop/MHT_Calculations/4H3S.pdb
# /Users/ntw/Desktop/MHT_Calculations/6KTZ.pdb
# /Users/ntw/Desktop/MHT_Calculations/1N11.pdb
# /Users/ntw/Desktop/MHT_Calculations/7X09.pdb
# /Users/ntw/Desktop/MHT_Calculations/6ZVO.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VQU.pdb
# /Users/ntw/Desktop/MHT_Calculations/4GOY.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VPS.pdb
# /Users/ntw/Desktop/MHT_Calculations/6ZWI.pdb
# /Users/ntw/Desktop/MHT_Calculations/1K63.pdb
# /Users/ntw/Desktop/MHT_Calculations/1K6E.pdb
# /Users/ntw/Desktop/MHT_Calculations/4MO1.pdb
# /Users/ntw/Desktop/MHT_Calculations/3TUU.pdb
# /Users/ntw/Desktop/MHT_Calculations/4OWB.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VJX.pdb
# /Users/ntw/Desktop/MHT_Calculations/7KQ9.pdb
# /Users/ntw/Desktop/MHT_Calculations/6KW0.pdb
# /Users/ntw/Desktop/MHT_Calculations/7F9U.pdb
# /Users/ntw/Desktop/MHT_Calculations/4IO1.pdb
# /Users/ntw/Desktop/MHT_Calculations/4YEM.pdb
# /Users/ntw/Desktop/MHT_Calculations/2CIX.pdb
# /Users/ntw/Desktop/MHT_Calculations/5L4H.pdb
# /Users/ntw/Desktop/MHT_Calculations/3SRG.pdb
# /Users/ntw/Desktop/MHT_Calculations/5DZ6.pdb
# /Users/ntw/Desktop/MHT_Calculations/6QML.pdb
# /Users/ntw/Desktop/MHT_Calculations/8QCU.pdb
# /Users/ntw/Desktop/MHT_Calculations/8OKM.pdb
# /Users/ntw/Desktop/MHT_Calculations/5JSP.pdb
# /Users/ntw/Desktop/MHT_Calculations/4HC6.pdb
# /Users/ntw/Desktop/MHT_Calculations/5GXZ.pdb
# /Users/ntw/Desktop/MHT_Calculations/8Y9X.pdb
# /Users/ntw/Desktop/MHT_Calculations/2RC7.pdb
# /Users/ntw/Desktop/MHT_Calculations/1NUF.pdb
# /Users/ntw/Desktop/MHT_Calculations/1L9M.pdb
# /Users/ntw/Desktop/MHT_Calculations/6HTM.pdb
# /Users/ntw/Desktop/MHT_Calculations/4ERR.pdb
# /Users/ntw/Desktop/MHT_Calculations/1NUD.pdb
# /Users/ntw/Desktop/MHT_Calculations/2IUO.pdb
# /Users/ntw/Desktop/MHT_Calculations/5GXY.pdb
# /Users/ntw/Desktop/MHT_Calculations/2WPF.pdb
# /Users/ntw/Desktop/MHT_Calculations/6PKY.pdb
# /Users/ntw/Desktop/MHT_Calculations/8PQE.pdb
# /Users/ntw/Desktop/MHT_Calculations/5JSR.pdb
# /Users/ntw/Desktop/MHT_Calculations/6AQK.pdb
# /Users/ntw/Desktop/MHT_Calculations/6H42.pdb
# /Users/ntw/Desktop/MHT_Calculations/7LGT.pdb
# /Users/ntw/Desktop/MHT_Calculations/6TQD.pdb
# /Users/ntw/Desktop/MHT_Calculations/6VHW.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OLT.pdb
# /Users/ntw/Desktop/MHT_Calculations/6H45.pdb
# /Users/ntw/Desktop/MHT_Calculations/6VHT.pdb
# /Users/ntw/Desktop/MHT_Calculations/5C5V.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VOT.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VO5.pdb
# /Users/ntw/Desktop/MHT_Calculations/2XMD.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OCN.pdb
# /Users/ntw/Desktop/MHT_Calculations/6P1M.pdb
# /Users/ntw/Desktop/MHT_Calculations/6VHU.pdb
# /Users/ntw/Desktop/MHT_Calculations/6VHX.pdb
# /Users/ntw/Desktop/MHT_Calculations/8SA7.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OLM.pdb
# /Users/ntw/Desktop/MHT_Calculations/7VTI.pdb
# /Users/ntw/Desktop/MHT_Calculations/6PDK.pdb
# /Users/ntw/Desktop/MHT_Calculations/8R11.pdb
# /Users/ntw/Desktop/MHT_Calculations/7QFK.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VL4.pdb
# /Users/ntw/Desktop/MHT_Calculations/4GP0.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VMF.pdb
# /Users/ntw/Desktop/MHT_Calculations/2HEK.pdb
# /Users/ntw/Desktop/MHT_Calculations/6T38.pdb
# /Users/ntw/Desktop/MHT_Calculations/6BZQ.pdb
# /Users/ntw/Desktop/MHT_Calculations/5U2P.pdb
# /Users/ntw/Desktop/MHT_Calculations/3F75.pdb
# /Users/ntw/Desktop/MHT_Calculations/6EQQ.pdb
# /Users/ntw/Desktop/MHT_Calculations/7QQ7.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OLO.pdb
# /Users/ntw/Desktop/MHT_Calculations/8HUF.pdb
# /Users/ntw/Desktop/MHT_Calculations/4GP3.pdb
# /Users/ntw/Desktop/MHT_Calculations/4LU4.pdb
# /Users/ntw/Desktop/MHT_Calculations/7KM9.pdb
# /Users/ntw/Desktop/MHT_Calculations/6VHZ.pdb
# /Users/ntw/Desktop/MHT_Calculations/8R16.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OLK.pdb
# /Users/ntw/Desktop/MHT_Calculations/6BZT.pdb
# /Users/ntw/Desktop/MHT_Calculations/5GY0.pdb
# /Users/ntw/Desktop/MHT_Calculations/5GY1.pdb
# /Users/ntw/Desktop/MHT_Calculations/3D7R.pdb
# /Users/ntw/Desktop/MHT_Calculations/2HI8.pdb
# /Users/ntw/Desktop/MHT_Calculations/6XQP.pdb
# /Users/ntw/Desktop/MHT_Calculations/8B56.pdb
# /Users/ntw/Desktop/MHT_Calculations/6RRV.pdb
# /Users/ntw/Desktop/MHT_Calculations/1KJL.pdb
# /Users/ntw/Desktop/MHT_Calculations/8R14.pdb
# /Users/ntw/Desktop/MHT_Calculations/8A9P.pdb
# /Users/ntw/Desktop/MHT_Calculations/6GVA.pdb
# /Users/ntw/Desktop/MHT_Calculations/2WBK.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OP6.pdb
# /Users/ntw/Desktop/MHT_Calculations/7OP7.pdb
# /Users/ntw/Desktop/MHT_Calculations/8P5Y.pdb
# /Users/ntw/Desktop/MHT_Calculations/4OWH.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VPM.pdb
# /Users/ntw/Desktop/MHT_Calculations/4CO6.pdb
# /Users/ntw/Desktop/MHT_Calculations/4R6C.pdb
# /Users/ntw/Desktop/MHT_Calculations/2XQG.pdb
# /Users/ntw/Desktop/MHT_Calculations/6ZWE.pdb
# /Users/ntw/Desktop/MHT_Calculations/7YUG.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VF3.pdb
# /Users/ntw/Desktop/MHT_Calculations/7SWS.pdb
# /Users/ntw/Desktop/MHT_Calculations/3K9U.pdb
# /Users/ntw/Desktop/MHT_Calculations/4GOV.pdb
# /Users/ntw/Desktop/MHT_Calculations/3GUD.pdb
# /Users/ntw/Desktop/MHT_Calculations/4B0O.pdb
# /Users/ntw/Desktop/MHT_Calculations/8GN1.pdb
# /Users/ntw/Desktop/MHT_Calculations/4Q1U.pdb
# /Users/ntw/Desktop/MHT_Calculations/6KU2.pdb
# /Users/ntw/Desktop/MHT_Calculations/6W0S.pdb
# /Users/ntw/Desktop/MHT_Calculations/8CX9.pdb
# /Users/ntw/Desktop/MHT_Calculations/2VR4.pdb
# Created /Users/ntw/Desktop/MHT_Calculations/run_all.py to process all PDB files!

# %%
# Out:
# Atoms Br at (19.523, 36.504, 2.969) and C at (19.464, 36.512, 3.176) are 0.2154 Ångströms apart

# %%
# Out:
# /Users/ntw/Desktop/MHT_Calculations/4GOV/4GOV/4GOV.xyz
# Atoms N at (54.561, -23.048, -33.096) and N at (54.561, -23.048, -33.096) are 0.0000 Ångströms apart
# Atoms C at (54.129, -24.396, -32.753) and C at (54.137, -24.386, -32.733) are 0.0237 Ångströms apart
# Atoms C at (53.398, -25.04, -33.94) and C at (53.376, -25.015, -33.892) are 0.0584 Ångströms apart
# Atoms H at (54.632, -22.798, -34.072) and H at (54.627, -22.804, -34.074) are 0.0081 Ångströms apart
# Atoms H at (53.444, -24.341, -31.907) and H at (53.471, -24.32, -31.873) are 0.0482 Ångströms apart
# Atoms H at (54.111, -25.16, -34.756) and H at (54.051, -25.115, -34.742) are 0.0763 Ångströms apart
# Atoms N at (17.644, -12.002, -6.369) and N at (17.644, -12.002, -6.369) are 0.0000 Ångströms apart
# Atoms C at (17.821, -11.371, -5.07) and C at (17.843, -11.386, -5.066) are 0.0269 Ångströms apart
# Atoms C at (17.303, -9.935, -5.079) and C at (17.406, -9.918, -5.05) are 0.1083 Ångströms apart
# Atoms H at (16.71, -12.112, -6.738) and H at (16.708, -12.1, -6.735) are 0.0125 Ångströms apart
# Atoms H at (18.882, -11.363, -4.822) and H at (18.904, -11.432, -4.822) are 0.0724 Ångströms apart
# Atoms H at (18.122, -8.214, -5.534) and H at (18.122, -8.214, -5.534) are 0.0000 Ångströms apart
# Atoms N at (10.843, -40.987, -14.016) and N at (10.843, -40.987, -14.016) are 0.0000 Ångströms apart
# Atoms C at (11.267, -42.378, -13.889) and C at (11.29, -42.367, -13.885) are 0.0258 Ångströms apart
# Atoms C at (10.181, -43.193, -13.182) and C at (10.256, -43.186, -13.109) are 0.1049 Ångströms apart
# Atoms H at (9.861, -40.772, -13.919) and H at (9.859, -40.78, -13.924) are 0.0096 Ångströms apart
# Atoms H at (12.181, -42.417, -13.297) and H at (12.227, -42.375, -13.328) are 0.0696 Ångströms apart
# Atoms H at (9.3, -43.214, -13.824) and H at (9.369, -43.307, -13.731) are 0.1485 Ångströms apart
# Atoms N at (11.559, -55.314, -9.447) and N at (11.559, -55.314, -9.447) are 0.0000 Ångströms apart
# Atoms C at (10.957, -54.277, -10.283) and C at (10.955, -54.271, -10.259) are 0.0248 Ångströms apart
# Atoms C at (11.655, -54.208, -11.641) and C at (11.695, -54.143, -11.587) are 0.0935 Ångströms apart
# Atoms H at (11.535, -56.274, -9.759) and H at (11.539, -56.271, -9.769) are 0.0112 Ångströms apart
# Atoms H at (11.089, -53.317, -9.783) and H at (11.065, -53.327, -9.724) are 0.0645 Ångströms apart
# Atoms H at (12.758, -54.018, -11.379) and H at (12.731, -54.285, -11.486) are 0.2889 Ångströms apart
# Atoms N at (32.519, -33.762, -19.819) and N at (32.519, -33.762, -19.819) are 0.0000 Ångströms apart
# Atoms C at (33.743, -33.85, -20.594) and C at (33.726, -33.797, -20.637) are 0.0703 Ångströms apart
# Atoms H at (31.726, -33.259, -20.191) and H at (31.71, -33.277, -20.179) are 0.0269 Ångströms apart
# Atoms H at (34.158, -34.848, -20.45) and H at (34.13, -34.809, -20.643) are 0.1989 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/4H3S/4H3S/4H3S.xyz
# Atoms N at (-97.407, 9.767, 1.56) and N at (-97.394, 9.751, 1.571) are 0.0234 Ångströms apart
# Atoms C at (-97.811, 10.406, 2.806) and C at (-97.815, 10.409, 2.799) are 0.0086 Ångströms apart
# Atoms C at (-97.124, 9.699, 3.964) and C at (-97.168, 9.689, 3.978) are 0.0472 Ångströms apart
# Atoms O at (-96.783, 8.521, 3.863) and O at (-96.891, 8.494, 3.902) are 0.1180 Ångströms apart
# Atoms C at (-99.326, 10.321, 2.991) and C at (-99.34, 10.372, 2.909) are 0.0976 Ångströms apart
# Atoms H at (-97.542, 11.348, 2.803) and H at (-97.519, 11.343, 2.795) are 0.0249 Ångströms apart
# Atoms H at (-99.593, 9.391, 2.93) and H at (-99.617, 9.453, 3.056) are 0.1425 Ångströms apart
# Atoms N at (-97.314, 5.774, 5.005) and N at (-97.291, 5.794, 5.012) are 0.0313 Ångströms apart
# Atoms C at (-97.846, 4.994, 3.894) and C at (-97.818, 5.094, 3.846) are 0.1144 Ångströms apart
# Atoms H at (-96.924, 6.505, 4.774) and H at (-96.872, 6.518, 4.814) are 0.0669 Ångströms apart
# Atoms H at (-95.274, 4.843, 4.227) and H at (-95.248, 5.006, 4.092) are 0.2132 Ångströms apart
# Atoms N at (-83.881, 17.366, 10.295) and N at (-83.869, 17.381, 10.307) are 0.0226 Ångströms apart
# Atoms C at (-82.615, 17.247, 11.011) and C at (-82.646, 17.32, 11.092) are 0.1134 Ångströms apart
# Atoms C at (-81.499, 17.931, 10.237) and C at (-81.463, 17.827, 10.281) are 0.1185 Ångströms apart
# Atoms H at (-84.142, 16.631, 9.932) and H at (-84.086, 16.642, 9.924) are 0.0576 Ångströms apart
# Atoms H at (-82.687, 17.65, 11.9) and H at (-82.742, 17.889, 11.884) are 0.2458 Ångströms apart
# Atoms N at (-66.953, 8.691, 8.894) and N at (-66.946, 8.685, 8.897) are 0.0097 Ångströms apart
# Atoms C at (-65.519, 8.466, 8.744) and C at (-65.519, 8.425, 8.761) are 0.0444 Ångströms apart
# Atoms C at (-64.71, 9.353, 9.688) and C at (-64.696, 9.342, 9.662) are 0.0315 Ångströms apart
# Atoms O at (-64.996, 10.542, 9.817) and O at (-64.961, 10.54, 9.735) are 0.0892 Ångströms apart
# Atoms C at (-65.091, 8.735, 7.299) and C at (-65.077, 8.596, 7.307) are 0.1399 Ångströms apart
# Atoms H at (-67.273, 9.271, 8.345) and H at (-67.253, 9.273, 8.349) are 0.0205 Ångströms apart
# Atoms H at (-65.317, 7.531, 8.955) and H at (-65.337, 7.499, 9.025) are 0.0795 Ångströms apart
# Atoms N at (-69.456, 24.903, 11.275) and N at (-69.434, 24.89, 11.272) are 0.0257 Ångströms apart
# Atoms C at (-70.069, 26.21, 11.475) and C at (-69.98, 26.225, 11.476) are 0.0903 Ångströms apart
# Atoms C at (-70.539, 26.815, 10.153) and C at (-70.516, 26.809, 10.171) are 0.0298 Ångströms apart
# Atoms O at (-71.596, 27.441, 10.095) and O at (-71.588, 27.41, 10.143) are 0.0577 Ångströms apart
# Atoms C at (-69.102, 27.159, 12.186) and C at (-68.9, 27.141, 12.058) are 0.2398 Ångströms apart
# Atoms H at (-68.611, 24.879, 11.43) and H at (-68.59, 24.837, 11.426) are 0.0471 Ångströms apart
# Atoms H at (-70.856, 26.102, 12.049) and H at (-70.72, 26.177, 12.117) are 0.1695 Ångströms apart
# Atoms H at (-68.269, 27.186, 11.689) and H at (-68.131, 27.133, 11.465) are 0.2684 Ångströms apart
# Atoms H at (-69.496, 28.045, 12.214) and H at (-69.255, 28.041, 12.123) are 0.2576 Ångströms apart
# Atoms H at (-68.293, 25.908, 13.603) and H at (-68.307, 25.763, 13.464) are 0.2014 Ångströms apart
# Atoms H at (-69.011, 26.208, 9.101) and H at (-69.014, 26.204, 9.09) are 0.0121 Ångströms apart
# Atoms N at (-84.647, 21.39, 13.454) and N at (-84.634, 21.376, 13.424) are 0.0356 Ångströms apart
# Atoms C at (-85.335, 21.144, 14.719) and C at (-85.367, 21.054, 14.641) are 0.1233 Ångströms apart
# Atoms C at (-84.382, 20.476, 15.7) and C at (-84.42, 20.438, 15.667) are 0.0631 Ångströms apart
# Atoms O at (-84.586, 20.528, 16.912) and O at (-84.663, 20.494, 16.872) are 0.0932 Ångströms apart
# Atoms H at (-84.889, 20.873, 12.811) and H at (-84.846, 20.875, 12.758) are 0.0683 Ångströms apart
# Atoms H at (-85.617, 22.001, 15.103) and H at (-85.765, 21.866, 15.02) are 0.2168 Ångströms apart
# Atoms H at (-83.191, 19.784, 14.322) and H at (-83.163, 19.811, 14.326) are 0.0391 Ångströms apart
# Atoms N at (-75.273, 2.085, 19.027) and N at (-75.248, 2.113, 19.005) are 0.0435 Ångströms apart
# Atoms C at (-76.412, 1.351, 18.491) and C at (-76.429, 1.445, 18.479) are 0.0963 Ångströms apart
# Atoms C at (-76.068, 0.701, 17.16) and C at (-76.103, 0.747, 17.163) are 0.0579 Ångströms apart
# Atoms O at (-76.541, -0.395, 16.854) and O at (-76.613, -0.337, 16.877) are 0.0953 Ångströms apart
# Atoms C at (-77.629, 2.264, 18.335) and C at (-77.559, 2.459, 18.273) are 0.2163 Ångströms apart
# Atoms H at (-75.378, 2.938, 19.051) and H at (-75.311, 2.971, 19.01) are 0.0852 Ångströms apart
# Atoms H at (-76.652, 0.638, 19.119) and H at (-76.733, 0.77, 19.12) are 0.1549 Ångströms apart
# Atoms H at (-77.936, 2.84, 20.279) and H at (-77.842, 2.596, 20.309) are 0.2632 Ångströms apart
# Atoms H at (-74.91, 2.147, 16.55) and H at (-74.88, 2.132, 16.554) are 0.0338 Ångströms apart
# Atoms N at (-57.631, -6.709, -3.386) and N at (-57.633, -6.684, -3.426) are 0.0472 Ångströms apart
# Atoms C at (-57.499, -7.344, -4.691) and C at (-57.575, -7.324, -4.738) are 0.0916 Ångströms apart
# Atoms C at (-58.353, -8.605, -4.748) and C at (-58.37, -8.625, -4.763) are 0.0302 Ångströms apart
# Atoms O at (-59.031, -8.865, -5.742) and O at (-59.026, -8.939, -5.757) are 0.0757 Ångströms apart
# Atoms C at (-56.034, -7.702, -4.969) and C at (-56.125, -7.583, -5.159) are 0.2420 Ångströms apart
# Atoms H at (-56.925, -6.77, -2.899) and H at (-56.9, -6.727, -2.978) are 0.0934 Ångströms apart
# Atoms H at (-57.806, -6.728, -5.388) and H at (-57.973, -6.72, -5.399) are 0.1676 Ångströms apart
# Atoms H at (-55.359, -5.697, -4.892) and H at (-55.461, -5.731, -4.811) are 0.1346 Ångströms apart
# Atoms H at (-57.847, -9.208, -2.97) and H at (-57.845, -9.199, -2.973) are 0.0097 Ångströms apart
# Atoms N at (-66.194, -13.747, -13.62) and N at (-66.24, -13.755, -13.623) are 0.0468 Ångströms apart
# Atoms C at (-66.95, -14.645, -12.752) and C at (-67.126, -14.582, -12.817) are 0.1979 Ångströms apart
# Atoms C at (-66.971, -14.135, -11.317) and C at (-66.976, -14.264, -11.332) are 0.1300 Ångströms apart
# Atoms H at (-65.51, -14.123, -13.981) and H at (-65.549, -14.163, -13.932) are 0.0743 Ångströms apart
# Atoms N at (-57.501, -6.723, 17.856) and N at (-57.483, -6.718, 17.821) are 0.0397 Ångströms apart
# Atoms C at (-56.721, -7.911, 17.524) and C at (-56.658, -7.888, 17.55) are 0.0719 Ångströms apart
# Atoms H at (-58.351, -6.85, 17.841) and H at (-58.33, -6.853, 17.747) are 0.0964 Ångströms apart
# Atoms H at (-57.558, -6.641, 15.464) and H at (-57.409, -6.482, 15.512) are 0.2231 Ångströms apart
# Atoms N at (-64.856, -1.48, 9.106) and N at (-64.864, -1.465, 9.093) are 0.0214 Ångströms apart
# Atoms C at (-63.431, -1.598, 8.838) and C at (-63.432, -1.555, 8.838) are 0.0430 Ångströms apart
# Atoms C at (-62.631, -1.251, 10.088) and C at (-62.652, -1.292, 10.121) are 0.0567 Ångströms apart
# Atoms O at (-63.1, -0.507, 10.95) and O at (-63.156, -0.646, 11.04) are 0.1748 Ångströms apart
# Atoms C at (-63.022, -0.676, 7.687) and C at (-63.005, -0.521, 7.797) are 0.1908 Ångströms apart
# Atoms H at (-65.083, -0.733, 9.467) and H at (-65.105, -0.716, 9.44) are 0.0388 Ångströms apart
# Atoms H at (-63.223, -2.521, 8.584) and H at (-63.207, -2.45, 8.507) are 0.1060 Ångströms apart
# Atoms H at (-62.061, -0.729, 7.571) and H at (-62.055, -0.623, 7.634) are 0.1235 Ångströms apart
# Atoms N at (-79.45, 5.905, -6.618) and N at (-79.416, 5.895, -6.641) are 0.0422 Ångströms apart
# Atoms C at (-80.661, 5.103, -6.754) and C at (-80.642, 5.127, -6.844) are 0.0951 Ångströms apart
# Atoms C at (-80.361, 3.616, -6.609) and C at (-80.4, 3.626, -6.713) are 0.1115 Ångströms apart
# Atoms O at (-81.147, 2.872, -6.021) and O at (-81.258, 2.887, -6.232) are 0.2389 Ångströms apart
# Atoms C at (-81.355, 5.35, -8.091) and C at (-81.242, 5.437, -8.219) are 0.1916 Ångströms apart
# Atoms H at (-79.243, 6.367, -7.313) and H at (-79.168, 6.344, -7.331) are 0.0805 Ångströms apart
# Atoms H at (-81.286, 5.353, -6.041) and H at (-81.297, 5.388, -6.163) are 0.1274 Ångströms apart
# Atoms H at (-78.65, 3.686, -7.542) and H at (-78.612, 3.69, -7.476) are 0.0763 Ångströms apart
# Atoms N at (-60.533, 19.549, -4.415) and N at (-60.534, 19.566, -4.438) are 0.0286 Ångströms apart
# Atoms C at (-59.154, 19.522, -4.889) and C at (-59.139, 19.54, -4.861) are 0.0365 Ångströms apart
# Atoms C at (-58.848, 20.704, -5.8) and C at (-58.819, 20.68, -5.829) are 0.0475 Ångströms apart
# Atoms O at (-57.848, 21.396, -5.619) and O at (-57.772, 21.319, -5.718) are 0.1466 Ångströms apart
# Atoms C at (-58.883, 18.213, -5.635) and C at (-58.812, 18.19, -5.506) are 0.1490 Ångströms apart
# Atoms H at (-60.986, 18.85, -4.629) and H at (-60.99, 18.884, -4.695) are 0.0744 Ångströms apart
# Atoms H at (-58.549, 19.565, -4.119) and H at (-58.566, 19.644, -4.073) are 0.0930 Ångströms apart
# Atoms N at (-56.691, 24.263, -5.188) and N at (-56.689, 24.286, -5.194) are 0.0239 Ångströms apart
# Atoms C at (-55.59, 24.714, -6.032) and C at (-55.555, 24.738, -5.99) are 0.0597 Ångströms apart
# Atoms C at (-55.726, 26.2, -6.34) and C at (-55.715, 26.205, -6.383) are 0.0447 Ångströms apart
# Atoms O at (-54.743, 26.94, -6.326) and O at (-54.731, 26.939, -6.47) are 0.1445 Ångströms apart
# Atoms C at (-55.552, 23.915, -7.338) and C at (-55.381, 23.868, -7.236) are 0.2046 Ångströms apart
# Atoms O at (-54.548, 22.229, -9.356) and N at (-54.722, 22.081, -9.502) are 0.2711 Ångströms apart
# Atoms H at (-57.201, 23.681, -5.562) and H at (-57.206, 23.727, -5.594) are 0.0563 Ångströms apart
# Atoms H at (-54.742, 24.573, -5.56) and H at (-54.74, 24.658, -5.453) are 0.1367 Ångströms apart
# Atoms H at (-57.65, 26.125, -6.634) and H at (-57.651, 26.127, -6.604) are 0.0301 Ångströms apart
# Atoms N at (-58.966, 34.834, -3.772) and N at (-58.945, 34.823, -3.747) are 0.0345 Ångströms apart
# Atoms C at (-58.612, 35.371, -2.459) and C at (-58.493, 35.32, -2.454) are 0.1296 Ångströms apart
# Atoms C at (-58.837, 34.37, -1.329) and C at (-58.918, 34.431, -1.284) are 0.1109 Ångströms apart
# Atoms H at (-59.713, 35.136, -4.073) and H at (-59.705, 35.132, -4.005) are 0.0686 Ångströms apart
# Atoms N at (-70.58, 37.386, -2.538) and N at (-70.561, 37.384, -2.543) are 0.0197 Ångströms apart
# Atoms C at (-70.723, 38.032, -3.834) and C at (-70.729, 38.034, -3.837) are 0.0070 Ångströms apart
# Atoms C at (-71.926, 38.972, -3.856) and C at (-71.888, 39.021, -3.782) are 0.0965 Ångströms apart
# Atoms O at (-71.937, 39.961, -4.589) and O at (-71.83, 40.095, -4.383) are 0.2680 Ångströms apart
# Atoms C at (-70.863, 36.974, -4.927) and C at (-70.984, 36.986, -4.925) are 0.1216 Ångströms apart
# Atoms C at (-71.162, 37.539, -6.299) and C at (-71.259, 37.554, -6.317) are 0.0998 Ångströms apart
# Atoms H at (-70.688, 36.534, -2.56) and H at (-70.641, 36.528, -2.571) are 0.0486 Ångströms apart
# Atoms H at (-69.919, 38.56, -4.021) and H at (-69.912, 38.525, -4.065) are 0.0567 Ångströms apart
# Atoms H at (-70.033, 36.476, -4.988) and H at (-70.203, 36.414, -4.992) are 0.1810 Ångströms apart
# Atoms H at (-71.589, 36.375, -4.69) and H at (-71.755, 36.456, -4.668) are 0.1860 Ångströms apart
# Atoms H at (-72.012, 38.006, -6.276) and H at (-71.901, 38.277, -6.244) are 0.2946 Ångströms apart
# Atoms H at (-72.967, 37.944, -2.57) and H at (-72.994, 37.912, -2.622) are 0.0668 Ångströms apart
# Atoms N at (-76.499, 33.301, -13.446) and N at (-76.489, 33.285, -13.451) are 0.0195 Ångströms apart
# Atoms C at (-76.23, 34.725, -13.297) and C at (-76.193, 34.707, -13.346) are 0.0640 Ångströms apart
# Atoms C at (-77.33, 35.581, -13.929) and C at (-77.328, 35.547, -13.925) are 0.0343 Ångströms apart
# Atoms O at (-77.623, 36.675, -13.447) and O at (-77.634, 36.626, -13.419) are 0.0575 Ångströms apart
# Atoms C at (-74.858, 35.067, -13.878) and C at (-74.881, 35.019, -14.067) are 0.1964 Ångströms apart
# Atoms H at (-75.941, 32.887, -13.953) and H at (-75.934, 32.85, -13.943) are 0.0390 Ångströms apart
# Atoms H at (-76.207, 34.938, -12.341) and H at (-76.088, 34.945, -12.401) are 0.1335 Ångströms apart
# Atoms N at (-77.946, 35.083, -14.997) and N at (-77.95, 35.045, -14.987) are 0.0395 Ångströms apart
# Atoms C at (-79.073, 35.783, -15.604) and C at (-79.063, 35.74, -15.62) are 0.0470 Ångströms apart
# Atoms C at (-80.262, 35.811, -14.65) and C at (-80.273, 35.787, -14.69) are 0.0479 Ångströms apart
# Atoms O at (-80.96, 36.819, -14.546) and O at (-80.991, 36.785, -14.639) are 0.1038 Ångströms apart
# Atoms C at (-79.485, 35.125, -16.923) and C at (-79.438, 35.052, -16.934) are 0.0875 Ångströms apart
# Atoms H at (-77.733, 34.347, -15.386) and H at (-77.744, 34.299, -15.362) are 0.0548 Ångströms apart
# Atoms H at (-78.812, 36.708, -15.794) and H at (-78.796, 36.661, -15.822) are 0.0570 Ångströms apart
# Atoms H at (-80.017, 33.985, -14.012) and H at (-80.003, 33.993, -13.986) are 0.0306 Ångströms apart
# Atoms N at (-83.071, 43.06, -10.543) and N at (-83.116, 43.099, -10.534) are 0.0602 Ångströms apart
# Atoms C at (-83.849, 44.004, -11.339) and C at (-83.8, 44.186, -11.226) are 0.2198 Ångströms apart
# Atoms C at (-85.128, 44.394, -10.609) and C at (-85.184, 44.421, -10.626) are 0.0645 Ångströms apart
# Atoms O at (-85.532, 45.556, -10.604) and O at (-85.731, 45.517, -10.739) are 0.2436 Ångströms apart
# Atoms H at (-82.814, 42.372, -10.991) and H at (-82.96, 42.402, -11.014) are 0.1508 Ångströms apart
# Atoms H at (-85.412, 42.616, -9.886) and H at (-85.388, 42.628, -9.877) are 0.0283 Ångströms apart
# Atoms N at (-86.038, 44.019, -7.23) and N at (-85.998, 44.048, -7.289) are 0.0770 Ångströms apart
# Atoms C at (-86.127, 44.347, -5.805) and C at (-85.968, 44.148, -5.833) are 0.2563 Ångströms apart
# Atoms C at (-84.975, 45.169, -5.233) and C at (-85.046, 45.228, -5.256) are 0.0951 Ångströms apart
# Atoms H at (-85.251, 43.82, -7.513) and H at (-85.22, 43.99, -7.651) are 0.2211 Ångströms apart
# Atoms N at (-72.936, 66.454, 2.263) and N at (-72.922, 66.42, 2.239) are 0.0439 Ångströms apart
# Atoms C at (-71.796, 65.547, 2.354) and C at (-71.863, 65.427, 2.387) are 0.1413 Ångströms apart
# Atoms C at (-71.679, 64.644, 1.132) and C at (-71.648, 64.613, 1.114) are 0.0474 Ångströms apart
# Atoms O at (-71.529, 63.426, 1.246) and O at (-71.397, 63.409, 1.177) are 0.1499 Ångströms apart
# Atoms H at (-72.742, 67.264, 2.474) and H at (-72.673, 67.229, 2.394) are 0.1113 Ångströms apart
# Atoms H at (-70.978, 66.085, 2.397) and H at (-71.023, 65.883, 2.602) are 0.2913 Ångströms apart
# Atoms H at (-71.886, 66.114, -0.118) and H at (-71.904, 66.112, -0.106) are 0.0217 Ångströms apart
# Atoms N at (-54.407, 22.153, -21.576) and N at (-54.351, 22.128, -21.583) are 0.0617 Ångströms apart
# Atoms C at (-53.338, 22.381, -20.609) and C at (-53.297, 22.255, -20.58) are 0.1356 Ångströms apart
# Atoms C at (-53.831, 22.42, -19.16) and C at (-53.849, 22.455, -19.168) are 0.0402 Ångströms apart
# Atoms O at (-53.124, 22.906, -18.277) and O at (-53.21, 23.088, -18.327) are 0.2074 Ångströms apart
# Atoms H at (-54.692, 22.875, -21.945) and H at (-54.575, 22.867, -21.96) are 0.1182 Ångströms apart
# Atoms H at (-52.676, 21.663, -20.687) and H at (-52.774, 21.426, -20.575) are 0.2799 Ångströms apart
# Atoms H at (-51.829, 23.762, -20.401) and H at (-51.809, 23.618, -20.166) are 0.2763 Ångströms apart
# Atoms N at (-78.464, 56.075, 3.627) and N at (-78.461, 56.078, 3.627) are 0.0042 Ångströms apart
# Atoms C at (-79.828, 55.673, 3.959) and C at (-79.82, 55.672, 3.956) are 0.0086 Ångströms apart
# Atoms C at (-80.156, 54.294, 3.391) and C at (-80.084, 54.263, 3.437) are 0.0909 Ångströms apart
# Atoms O at (-80.954, 53.553, 3.965) and O at (-80.764, 53.471, 4.089) are 0.2412 Ångströms apart
# Atoms C at (-80.835, 56.707, 3.447) and C at (-80.832, 56.646, 3.352) are 0.1129 Ångströms apart
# Atoms H at (-78.417, 56.691, 3.029) and H at (-78.413, 56.698, 3.033) are 0.0090 Ångströms apart
# Atoms H at (-79.915, 55.625, 4.934) and H at (-79.934, 55.671, 4.929) are 0.0500 Ångströms apart
# Atoms H at (-79.02, 54.475, 1.818) and H at (-79.07, 54.496, 1.787) are 0.0625 Ångströms apart
# Atoms N at (-73.136, 42.626, 5.824) and N at (-73.138, 42.62, 5.819) are 0.0081 Ångströms apart
# Atoms C at (-72.71, 43.596, 4.823) and C at (-72.709, 43.597, 4.825) are 0.0024 Ångströms apart
# Atoms C at (-73.407, 43.362, 3.487) and C at (-73.402, 43.362, 3.485) are 0.0054 Ångströms apart
# Atoms O at (-73.834, 44.309, 2.824) and O at (-73.816, 44.31, 2.817) are 0.0193 Ångströms apart
# Atoms C at (-71.192, 43.533, 4.635) and C at (-71.191, 43.539, 4.636) are 0.0062 Ångströms apart
# Atoms C at (-70.395, 44.028, 5.833) and C at (-70.386, 43.768, 5.907) are 0.2705 Ångströms apart
# Atoms C at (-70.553, 45.527, 6.029) and H at (-70.513, 45.818, 5.974) are 0.2988 Ångströms apart
# Atoms H at (-72.51, 42.104, 6.097) and H at (-72.514, 42.091, 6.084) are 0.0188 Ångströms apart
# Atoms H at (-72.94, 44.497, 5.132) and H at (-72.944, 44.496, 5.136) are 0.0057 Ångströms apart
# Atoms H at (-70.937, 42.611, 4.47) and H at (-70.955, 42.663, 4.292) are 0.1863 Ångströms apart
# Atoms H at (-70.949, 44.081, 3.872) and H at (-70.932, 44.221, 3.997) are 0.1885 Ångströms apart
# Atoms H at (-69.455, 43.837, 5.693) and H at (-69.441, 43.781, 5.688) are 0.0579 Ångströms apart
# Atoms N at (-76.807, 44.896, 1.77) and N at (-76.809, 44.897, 1.798) are 0.0281 Ångströms apart
# Atoms C at (-76.874, 46.248, 1.225) and C at (-76.858, 46.227, 1.214) are 0.0286 Ångströms apart
# Atoms C at (-76.745, 46.241, -0.297) and C at (-76.693, 46.138, -0.295) are 0.1154 Ångströms apart
# Atoms C at (-75.781, 47.122, 1.842) and C at (-75.764, 47.114, 1.804) are 0.0424 Ångströms apart
# Atoms H at (-76.027, 44.669, 2.053) and H at (-76.043, 44.682, 2.124) are 0.0739 Ångströms apart
# Atoms H at (-77.742, 46.641, 1.454) and H at (-77.727, 46.637, 1.408) are 0.0485 Ångströms apart
# Atoms H at (-74.918, 46.717, 1.659) and H at (-74.899, 46.736, 1.581) are 0.0825 Ångströms apart
# Atoms H at (-78.438, 45.33, -0.602) and H at (-78.47, 45.404, -0.607) are 0.0808 Ångströms apart
# Atoms N at (-77.182, 52.695, -11.431) and N at (-77.203, 52.674, -11.438) are 0.0305 Ångströms apart
# Atoms C at (-77.747, 53.03, -12.734) and C at (-77.797, 52.942, -12.742) are 0.1015 Ångströms apart
# Atoms C at (-76.663, 53.064, -13.804) and C at (-76.732, 53.112, -13.823) are 0.0862 Ångströms apart
# Atoms O at (-75.635, 53.719, -13.632) and O at (-75.792, 53.893, -13.672) are 0.2377 Ångströms apart
# Atoms C at (-80.029, 53.905, -11.981) and H at (-80.261, 53.908, -11.885) are 0.2511 Ångströms apart
# Atoms H at (-77.44, 53.217, -10.798) and H at (-77.455, 53.215, -10.818) are 0.0251 Ångströms apart
# Atoms H at (-78.418, 52.359, -12.977) and H at (-78.361, 52.178, -12.984) are 0.1899 Ångströms apart
# Atoms H at (-78.816, 54.582, -13.555) and H at (-78.893, 54.473, -13.577) are 0.1353 Ångströms apart
# Atoms H at (-77.595, 51.872, -15.03) and H at (-77.563, 51.827, -15.017) are 0.0567 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/3D7R/3D7R/3D7R.xyz
# Atoms N at (26.935, 23.131, 1.36) and N at (26.935, 23.131, 1.36) are 0.0000 Ångströms apart
# Atoms C at (27.558, 22.002, 0.693) and C at (27.543, 21.988, 0.688) are 0.0211 Ångströms apart
# Atoms C at (26.816, 20.73, 1.059) and C at (26.763, 20.716, 0.99) are 0.0881 Ångströms apart
# Atoms H at (26.085, 22.979, 1.883) and H at (26.088, 22.984, 1.891) are 0.0099 Ångströms apart
# Atoms H at (28.588, 21.917, 1.041) and H at (28.566, 21.87, 1.046) are 0.0521 Ångströms apart
# Atoms H at (25.711, 20.876, 0.754) and H at (25.774, 20.815, 0.752) are 0.0877 Ångströms apart
# Atoms N at (77.115, 9.909, 50.037) and N at (77.115, 9.909, 50.037) are 0.0000 Ångströms apart
# Atoms C at (76.446, 10.755, 49.052) and C at (76.428, 10.741, 49.065) are 0.0262 Ångströms apart
# Atoms C at (77.175, 12.088, 48.898) and C at (77.103, 12.104, 48.982) are 0.1118 Ångströms apart
# Atoms H at (77.988, 10.226, 50.435) and H at (77.991, 10.228, 50.424) are 0.0116 Ångströms apart
# Atoms H at (75.425, 10.946, 49.383) and H at (75.4, 10.884, 49.398) are 0.0685 Ångströms apart
# Atoms H at (78.133, 11.982, 48.646) and H at (78.234, 11.901, 48.72) are 0.1491 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/6ZWE/6ZWE/6ZWE.xyz
# Atoms N at (-102.258, 26.446, 14.514) and N at (-102.257, 26.435, 14.522) are 0.0136 Ångströms apart
# Atoms C at (-102.409, 25.454, 13.46) and C at (-102.38, 25.447, 13.46) are 0.0298 Ångströms apart
# Atoms C at (-102.143, 26.001, 12.066) and C at (-102.027, 26.011, 12.089) are 0.1187 Ångströms apart
# Atoms C at (-103.817, 24.857, 13.499) and C at (-103.801, 24.878, 13.436) are 0.0683 Ångströms apart
# Atoms H at (-103.081, 26.896, 14.889) and H at (-103.087, 26.866, 14.902) are 0.0332 Ångströms apart
# Atoms H at (-101.697, 24.651, 13.649) and H at (-101.692, 24.63, 13.677) are 0.0354 Ångströms apart
# Atoms N at (-102.196, 27.321, 11.873) and N at (-102.196, 27.321, 11.873) are 0.0000 Ångströms apart
# Atoms H at (-102.275, 27.94, 12.667) and H at (-102.365, 27.936, 12.657) are 0.0906 Ångströms apart
# Atoms N at (-101.57, 9.652, 27.875) and N at (-101.57, 9.652, 27.875) are 0.0000 Ångströms apart
# Atoms C at (-101.884, 9.992, 29.258) and C at (-101.902, 9.946, 29.267) are 0.0502 Ångströms apart
# Atoms C at (-103.2, 9.327, 29.681) and C at (-103.155, 9.164, 29.678) are 0.1691 Ångströms apart
# Atoms H at (-102.065, 8.896, 27.423) and H at (-102.066, 8.908, 27.405) are 0.0217 Ångströms apart
# Atoms H at (-102.023, 11.072, 29.313) and H at (-102.12, 11.011, 29.35) are 0.1204 Ångströms apart
# Atoms H at (-103.495, 8.615, 28.91) and H at (-103.496, 8.579, 28.824) are 0.0932 Ångströms apart
# Atoms N at (-102.676, 16.958, 17.347) and N at (-102.676, 16.955, 17.355) are 0.0085 Ångströms apart
# Atoms C at (-101.506, 17.292, 16.539) and C at (-101.489, 17.301, 16.575) are 0.0408 Ångströms apart
# Atoms C at (-100.721, 16.057, 16.118) and C at (-100.708, 16.068, 16.136) are 0.0248 Ångströms apart
# Atoms O at (-100.056, 16.077, 15.076) and O at (-100.039, 16.1, 15.097) are 0.0355 Ångströms apart
# Atoms C at (-100.593, 18.251, 17.301) and C at (-100.589, 18.234, 17.388) are 0.0887 Ångströms apart
# Atoms H at (-102.677, 17.151, 18.338) and H at (-102.689, 17.14, 18.348) are 0.0191 Ångströms apart
# Atoms H at (-101.851, 17.798, 15.637) and H at (-101.813, 17.834, 15.681) are 0.0684 Ångströms apart
# Atoms H at (-100.405, 17.841, 18.293) and H at (-100.275, 17.715, 18.294) are 0.1810 Ångströms apart
# Atoms N at (-100.775, 14.983, 16.903) and N at (-100.775, 14.983, 16.903) are 0.0000 Ångströms apart
# Atoms H at (-101.397, 14.982, 17.699) and H at (-101.41, 14.973, 17.689) are 0.0187 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/7YUG/7YUG/7YUG.xyz
# Atoms N at (41.001, 40.677, 16.772) and N at (41.001, 40.677, 16.772) are 0.0000 Ångströms apart
# Atoms C at (40.4, 41.952, 17.209) and C at (40.396, 41.954, 17.201) are 0.0092 Ångströms apart
# Atoms C at (40.692, 43.044, 16.211) and C at (40.682, 43.083, 16.223) are 0.0420 Ångströms apart
# Atoms H at (41.413, 40.605, 15.852) and H at (41.417, 40.604, 15.854) are 0.0046 Ångströms apart
# Atoms H at (40.846, 42.232, 18.163) and H at (40.838, 42.225, 18.16) are 0.0110 Ångströms apart
# Atoms H at (41.769, 43.211, 16.184) and H at (41.755, 43.127, 16.038) are 0.1690 Ångströms apart
# Atoms N at (23.649, 32.918, 8.732) and N at (23.649, 32.918, 8.732) are 0.0000 Ångströms apart
# Atoms N at (23.649, 32.918, 8.732) and N at (23.649, 32.918, 8.732) are 0.0000 Ångströms apart
# Atoms N at (23.649, 32.918, 8.732) and N at (23.649, 32.918, 8.732) are 0.0000 Ångströms apart
# Atoms C at (22.187, 32.882, 9.015) and C at (22.187, 32.883, 9.014) are 0.0014 Ångströms apart
# Atoms C at (22.187, 32.882, 9.015) and C at (22.2, 32.859, 8.992) are 0.0350 Ångströms apart
# Atoms C at (22.187, 32.883, 9.014) and C at (22.2, 32.859, 8.992) are 0.0351 Ångströms apart
# Atoms C at (21.55, 34.259, 8.754) and C at (21.55, 34.259, 8.753) are 0.0010 Ångströms apart
# Atoms C at (21.55, 34.259, 8.754) and C at (21.551, 34.19, 8.641) are 0.1324 Ångströms apart
# Atoms C at (21.55, 34.259, 8.753) and C at (21.551, 34.19, 8.641) are 0.1316 Ångströms apart
# Atoms C at (21.992, 35.365, 9.707) and C at (21.99, 35.365, 9.706) are 0.0022 Ångströms apart
# Atoms C at (21.992, 35.365, 9.707) and C at (21.742, 35.207, 9.719) are 0.2960 Ångströms apart
# Atoms C at (21.99, 35.365, 9.706) and C at (21.742, 35.207, 9.719) are 0.2943 Ångströms apart
# Atoms C at (21.28, 35.357, 11.056) and C at (21.276, 35.355, 11.054) are 0.0049 Ångströms apart
# Atoms N at (21.731, 36.362, 12.034) and N at (21.724, 36.362, 12.031) are 0.0076 Ångströms apart
# Atoms C at (21.212, 37.58, 12.187) and C at (21.204, 37.58, 12.183) are 0.0089 Ångströms apart
# Atoms N at (20.229, 38.013, 11.408) and N at (20.22, 38.011, 11.404) are 0.0100 Ångströms apart
# Atoms N at (21.674, 38.346, 13.161) and N at (21.666, 38.346, 13.157) are 0.0089 Ångströms apart
# Atoms H at (24.067, 33.772, 8.391) and H at (24.067, 33.772, 8.391) are 0.0000 Ångströms apart
# Atoms H at (24.067, 33.772, 8.391) and H at (24.064, 33.78, 8.408) are 0.0190 Ångströms apart
# Atoms H at (24.067, 33.772, 8.391) and H at (24.064, 33.78, 8.408) are 0.0190 Ångströms apart
# Atoms H at (22.059, 32.652, 10.073) and H at (22.059, 32.654, 10.072) are 0.0022 Ångströms apart
# Atoms H at (22.059, 32.652, 10.073) and H at (22.048, 32.671, 10.055) are 0.0284 Ångströms apart
# Atoms H at (22.059, 32.654, 10.072) and H at (22.048, 32.671, 10.055) are 0.0264 Ångströms apart
# Atoms H at (21.808, 34.564, 7.74) and H at (21.996, 34.566, 7.72) are 0.1891 Ångströms apart
# Atoms H at (21.808, 34.564, 7.74) and H at (21.79, 34.564, 7.734) are 0.0190 Ångströms apart
# Atoms H at (20.468, 34.152, 8.836) and H at (20.467, 34.157, 8.82) are 0.0168 Ångströms apart
# Atoms H at (21.996, 34.566, 7.72) and H at (21.79, 34.564, 7.734) are 0.2065 Ångströms apart
# Atoms H at (23.061, 35.254, 9.886) and H at (23.059, 35.255, 9.886) are 0.0022 Ångströms apart
# Atoms H at (23.061, 35.254, 9.886) and H at (22.795, 35.243, 9.999) are 0.2892 Ångströms apart
# Atoms H at (23.059, 35.255, 9.886) and H at (22.795, 35.243, 9.999) are 0.2874 Ångströms apart
# Atoms H at (21.818, 36.328, 9.227) and H at (21.815, 36.328, 9.226) are 0.0032 Ångströms apart
# Atoms H at (20.219, 35.524, 10.873) and H at (20.214, 35.519, 10.87) are 0.0077 Ångströms apart
# Atoms H at (21.4, 34.369, 11.5) and H at (21.398, 34.368, 11.499) are 0.0024 Ångströms apart
# Atoms H at (22.498, 36.107, 12.639) and H at (22.491, 36.108, 12.638) are 0.0071 Ångströms apart
# Atoms H at (19.869, 37.421, 10.673) and H at (19.86, 37.418, 10.67) are 0.0099 Ångströms apart
# Atoms H at (19.841, 38.935, 11.55) and H at (19.831, 38.932, 11.545) are 0.0116 Ångströms apart
# Atoms H at (22.413, 38.009, 13.761) and H at (22.406, 38.009, 13.757) are 0.0081 Ångströms apart
# Atoms H at (21.287, 39.268, 13.305) and H at (21.279, 39.268, 13.301) are 0.0089 Ångströms apart
# Atoms N at (23.245, 24.379, 34.719) and N at (23.245, 24.379, 34.719) are 0.0000 Ångströms apart
# Atoms C at (21.929, 25.032, 34.535) and C at (21.914, 24.985, 34.496) are 0.0629 Ångströms apart
# Atoms C at (21.406, 25.514, 35.835) and C at (21.232, 25.308, 35.809) are 0.2709 Ångströms apart
# Atoms H at (23.663, 24.348, 35.638) and H at (23.662, 24.38, 35.639) are 0.0320 Ångströms apart
# Atoms H at (21.232, 24.295, 34.136) and H at (21.302, 24.236, 33.993) are 0.1698 Ångströms apart
# Atoms H at (21.089, 24.665, 36.44) and H at (21.089, 24.385, 36.37) are 0.2886 Ångströms apart
# Atoms N at (20.155, 26.563, 29.678) and N at (20.155, 26.563, 29.678) are 0.0000 Ångströms apart
# Atoms C at (19.386, 27.753, 29.226) and C at (19.387, 27.752, 29.224) are 0.0024 Ångströms apart
# Atoms C at (19.136, 28.705, 30.393) and C at (19.132, 28.7, 30.393) are 0.0064 Ångströms apart
# Atoms C at (18.266, 28.048, 31.455) and C at (18.231, 28.036, 31.423) are 0.0489 Ångströms apart
# Atoms C at (18.022, 28.975, 32.611) and C at (18.045, 28.897, 32.628) are 0.0831 Ångströms apart
# Atoms H at (20.609, 26.545, 30.58) and H at (20.608, 26.545, 30.581) are 0.0014 Ångströms apart
# Atoms H at (18.407, 27.384, 28.921) and H at (18.409, 27.381, 28.917) are 0.0054 Ångströms apart
# Atoms H at (18.633, 29.598, 30.023) and H at (18.652, 29.607, 30.025) are 0.0211 Ångströms apart
# Atoms H at (20.082, 28.959, 30.86) and H at (20.091, 28.988, 30.836) are 0.0387 Ångströms apart
# Atoms H at (17.309, 27.775, 31.011) and H at (17.258, 27.846, 30.971) are 0.0961 Ångströms apart
# Atoms H at (18.762, 27.147, 31.817) and H at (18.675, 27.088, 31.727) are 0.1384 Ångströms apart
# Atoms H at (17.694, 29.887, 32.338) and H at (17.656, 29.929, 32.23) are 0.1220 Ångströms apart
# Atoms N at (18.419, 29.301, 24.298) and N at (18.419, 29.301, 24.298) are 0.0000 Ångströms apart
# Atoms C at (18.476, 30.594, 23.602) and C at (18.458, 30.6, 23.582) are 0.0276 Ångströms apart
# Atoms C at (19.252, 31.546, 24.418) and C at (19.164, 31.654, 24.371) are 0.1470 Ångströms apart
# Atoms H at (19.009, 29.15, 25.104) and H at (19.014, 29.157, 25.101) are 0.0091 Ångströms apart
# Atoms H at (17.46, 30.976, 23.501) and H at (17.428, 30.929, 23.444) are 0.0805 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/2HEK/2HEK/2HEK.xyz
# /Users/ntw/Desktop/MHT_Calculations/3F75/3F75/3F75.xyz
# Atoms N at (25.788, 10.749, 27.239) and N at (25.649, 10.733, 27.27) are 0.1433 Ångströms apart
# Atoms C at (26.232, 11.957, 26.546) and C at (26.026, 11.857, 26.447) are 0.2495 Ångströms apart
# Atoms C at (25.189, 13.068, 26.658) and C at (25.067, 13.024, 26.661) are 0.1297 Ångströms apart
# Atoms O at (24.572, 13.473, 25.673) and O at (24.361, 13.428, 25.735) are 0.2245 Ångströms apart
# Atoms H at (25.312, 10.026, 26.719) and H at (25.081, 10.011, 26.851) are 0.2665 Ångströms apart
# Atoms N at (25.029, 13.558, 27.879) and N at (25.029, 13.558, 27.879) are 0.0000 Ångströms apart
# Atoms H at (25.605, 13.188, 28.622) and H at (25.675, 13.236, 28.585) are 0.0926 Ångströms apart
# Atoms C at (39.104, -4.232, 21.216) and C at (39.104, -4.232, 21.216) are 0.0000 Ångströms apart
# Atoms C at (40.247, -4.663, 22.134) and C at (40.237, -4.666, 22.163) are 0.0308 Ångströms apart
# Atoms O at (39.742, -5.224, 23.322) and H at (39.801, -5.06, 23.081) are 0.2974 Ångströms apart
# Atoms H at (38.48, -5.103, 21.016) and H at (38.478, -5.102, 21.015) are 0.0024 Ångströms apart
# Atoms H at (40.847, -3.795, 22.404) and H at (40.86, -3.795, 22.378) are 0.0291 Ångströms apart
# Atoms C at (37.065, 12.238, 8.123) and C at (37.065, 12.238, 8.123) are 0.0000 Ångströms apart
# Atoms C at (54.297, 3.8, 35.519) and C at (54.297, 3.8, 35.519) are 0.0000 Ångströms apart
# Atoms C at (55.143, 3.803, 34.243) and C at (55.134, 3.712, 34.237) are 0.0916 Ångströms apart
# Atoms H at (54.322, 2.799, 35.949) and H at (54.298, 2.812, 35.98) are 0.0413 Ångströms apart
# Atoms C at (31.833, 20.382, 25.212) and C at (31.833, 20.382, 25.212) are 0.0000 Ångströms apart
# Atoms C at (32.694, 21.619, 24.947) and C at (32.676, 21.634, 24.978) are 0.0389 Ångströms apart
# Atoms C at (32.592, 22.062, 23.479) and C at (32.684, 22.046, 23.506) are 0.0972 Ångströms apart
# Atoms H at (32.345, 19.519, 24.787) and H at (32.362, 19.529, 24.787) are 0.0197 Ångströms apart
# Atoms H at (30.881, 20.507, 24.695) and H at (30.883, 20.498, 24.69) are 0.0105 Ångströms apart
# Atoms H at (32.355, 22.432, 25.588) and H at (32.266, 22.451, 25.571) are 0.0926 Ångströms apart
# Atoms H at (33.734, 21.389, 25.18) and H at (33.699, 21.44, 25.299) are 0.1341 Ångströms apart
# Atoms Cl at (33.598, 2.03, 12.368) and Br at (33.707, 1.98, 12.352) are 0.1210 Ångströms apart
# Atoms H at (46.592, 12.107, 54.747) and H at (46.592, 12.107, 54.747) are 0.0000 Ångströms apart
# Atoms H at (45.532, 12.847, 55.625) and H at (45.532, 12.847, 55.625) are 0.0000 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/4LU4/4LU4/4LU4.xyz
# Atoms N at (37.538, 21.59, -27.664) and N at (37.538, 21.59, -27.664) are 0.0000 Ångströms apart
# Atoms C at (38.807, 20.917, -27.922) and C at (38.777, 20.89, -27.953) are 0.0509 Ångströms apart
# Atoms H at (37.416, 22.557, -27.927) and H at (37.434, 22.566, -27.902) are 0.0321 Ångströms apart
# Atoms H at (38.591, 19.988, -28.45) and H at (38.479, 19.927, -28.367) are 0.1522 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/8B56/8B56/8B56.xyz
# Atoms N at (-19.516, 1.054, 22.04) and N at (-19.49, 1.047, 22.066) are 0.0374 Ångströms apart
# Atoms C at (-19.977, -0.01, 22.928) and C at (-19.846, -0.023, 22.994) are 0.1473 Ångströms apart
# Atoms C at (-20.362, -1.245, 22.133) and C at (-20.403, -1.218, 22.225) are 0.1043 Ångströms apart
# Atoms H at (-19.924, 1.802, 22.153) and H at (-19.931, 1.778, 22.173) are 0.0320 Ångströms apart
# Atoms H at (-19.26, -0.259, 23.532) and H at (-19.053, -0.307, 23.475) are 0.2200 Ångströms apart
# Atoms C at (6.081, -1.653, 45.073) and C at (6.083, -1.653, 45.075) are 0.0028 Ångströms apart
# Atoms C at (5.71, -2.301, 46.426) and C at (5.734, -2.269, 46.44) are 0.0424 Ångströms apart
# Atoms H at (7.51, -3.023, 44.927) and H at (7.51, -3.024, 44.926) are 0.0014 Ångströms apart
# Atoms H at (5.306, -1.765, 44.5) and H at (5.312, -1.782, 44.502) are 0.0181 Ångströms apart
# Atoms N at (11.731, -15.061, 9.435) and N at (11.712, -15.091, 9.458) are 0.0423 Ångströms apart
# Atoms C at (11.932, -15.735, 8.161) and C at (11.892, -15.912, 8.266) are 0.2097 Ångströms apart
# Atoms C at (10.63, -16.43, 7.76) and C at (10.55, -16.451, 7.788) are 0.0873 Ångströms apart
# Atoms O at (10.015, -17.157, 8.551) and O at (9.832, -17.114, 8.545) are 0.1881 Ångströms apart
# Atoms H at (12.28, -15.271, 10.062) and H at (12.283, -15.246, 10.082) are 0.0322 Ångströms apart
# Atoms H at (13.686, -16.465, 8.956) and H at (13.73, -16.698, 8.774) are 0.2989 Ångströms apart
# Atoms N at (8.291, -12.796, 3.915) and N at (8.31, -12.753, 3.93) are 0.0493 Ångströms apart
# Atoms C at (8.368, -12.181, 2.604) and C at (8.39, -12.061, 2.651) are 0.1307 Ångströms apart
# Atoms C at (7.07, -12.41, 1.86) and C at (7.153, -12.396, 1.826) are 0.0908 Ångströms apart
# Atoms O at (6.493, -13.502, 1.913) and O at (6.69, -13.542, 1.805) are 0.2282 Ångströms apart
# Atoms H at (8.929, -13.345, 4.09) and H at (8.95, -13.306, 4.088) are 0.0443 Ångströms apart
# Atoms H at (8.527, -11.23, 2.706) and H at (8.425, -11.102, 2.793) are 0.1854 Ångströms apart
# Atoms C at (6.851, 14.264, 31.436) and C at (6.849, 14.229, 31.474) are 0.0517 Ångströms apart
# Atoms C at (6.123, 15.621, 31.249) and C at (6.047, 15.534, 31.343) are 0.1489 Ångströms apart
# Atoms C at (6.176, 16.551, 32.524) and C at (5.991, 16.37, 32.651) are 0.2883 Ångströms apart
# Atoms H at (8.494, 15.343, 31.583) and H at (8.488, 15.342, 31.564) are 0.0199 Ångströms apart
# Atoms H at (6.432, 13.816, 32.187) and H at (6.496, 13.752, 32.242) are 0.1059 Ångströms apart
# Atoms H at (6.539, 16.1, 30.515) and H at (6.458, 16.084, 30.658) are 0.1651 Ångströms apart
# Atoms H at (5.19, 15.449, 31.046) and H at (5.136, 15.316, 31.092) are 0.1507 Ångströms apart
# Atoms H at (7.103, 16.626, 32.802) and H at (6.9, 16.553, 32.937) are 0.2545 Ångströms apart
# Atoms H at (5.036, 18.048, 31.602) and H at (5.204, 17.981, 31.599) are 0.1809 Ångströms apart
# Atoms C at (13.293, -15.323, 2.509) and C at (13.238, -15.49, 2.609) are 0.2023 Ångströms apart
# Atoms H at (12.831, -15.11, 1.547) and H at (12.885, -15.193, 1.623) are 0.1248 Ångströms apart
# Atoms H at (12.918, -16.303, 2.798) and H at (12.844, -16.493, 2.765) are 0.2066 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/2WBK/2WBK/2WBK.xyz
# Atoms N at (-43.327, 9.942, -19.763) and N at (-43.327, 9.942, -19.763) are 0.0000 Ångströms apart
# Atoms C at (-44.603, 9.775, -20.443) and C at (-44.604, 9.764, -20.44) are 0.0114 Ångströms apart
# Atoms C at (-45.159, 8.377, -20.205) and C at (-45.167, 8.365, -20.182) are 0.0271 Ångströms apart
# Atoms H at (-42.977, 9.195, -19.181) and H at (-42.975, 9.197, -19.179) are 0.0035 Ångströms apart
# Atoms H at (-44.437, 9.898, -21.513) and H at (-44.442, 9.876, -21.512) are 0.0226 Ångströms apart
# Atoms N at (-35.456, 13.891, -25.225) and N at (-35.456, 13.891, -25.225) are 0.0000 Ångströms apart
# Atoms C at (-34.058, 14.255, -24.982) and C at (-34.058, 14.271, -25.044) are 0.0640 Ångströms apart
# Atoms C at (-33.862, 14.574, -23.506) and C at (-33.82, 14.74, -23.617) are 0.2041 Ångströms apart
# Atoms H at (-35.76, 12.971, -24.94) and H at (-35.756, 12.982, -24.903) are 0.0388 Ångströms apart
# Atoms H at (-33.802, 15.13, -25.579) and H at (-33.827, 15.09, -25.725) are 0.1534 Ångströms apart
# Atoms N at (-42.557, -6.413, -41.135) and N at (-42.557, -6.413, -41.135) are 0.0000 Ångströms apart
# Atoms C at (-42.983, -5.127, -40.569) and C at (-42.949, -5.154, -40.509) are 0.0741 Ångströms apart
# Atoms H at (-41.778, -6.908, -40.725) and H at (-41.768, -6.915, -40.754) are 0.0315 Ångströms apart
# Atoms H at (-43.934, -4.882, -41.043) and H at (-43.956, -4.911, -40.848) are 0.1984 Ångströms apart
# Atoms N at (-30.272, -20.924, -33.61) and N at (-30.272, -20.924, -33.61) are 0.0000 Ångströms apart
# Atoms C at (-30.947, -20.331, -32.424) and C at (-30.94, -20.335, -32.435) are 0.0136 Ångströms apart
# Atoms C at (-32.473, -20.578, -32.361) and C at (-32.425, -20.669, -32.449) are 0.1354 Ångströms apart
# Atoms H at (-30.695, -21.715, -34.075) and H at (-30.695, -21.715, -34.074) are 0.0010 Ångströms apart
# Atoms H at (-30.788, -19.253, -32.458) and H at (-30.824, -19.252, -32.473) are 0.0390 Ångströms apart
# Atoms N at (-10.677, -26.393, -32.399) and N at (-10.677, -26.393, -32.399) are 0.0000 Ångströms apart
# Atoms C at (-9.314, -25.854, -32.545) and C at (-9.32, -25.827, -32.552) are 0.0285 Ångströms apart
# Atoms C at (-9.27, -24.703, -33.556) and C at (-9.321, -24.622, -33.494) are 0.1140 Ångströms apart
# Atoms H at (-11.324, -25.915, -31.788) and H at (-11.323, -25.928, -31.777) are 0.0171 Ångströms apart
# Atoms H at (-8.668, -26.653, -32.91) and H at (-8.662, -26.594, -32.961) are 0.0782 Ångströms apart
# Atoms N at (-24.015, -33.961, -43.951) and N at (-24.015, -33.961, -43.951) are 0.0000 Ångströms apart
# Atoms C at (-24.896, -33.513, -45.022) and C at (-24.885, -33.442, -45.0) are 0.0751 Ångströms apart
# Atoms H at (-23.72, -34.927, -43.944) and H at (-23.741, -34.933, -43.96) are 0.0271 Ångströms apart
# Atoms H at (-24.597, -32.525, -45.371) and H at (-24.608, -32.408, -45.205) are 0.2034 Ångströms apart
# Atoms N at (-19.911, -19.793, -32.381) and N at (-19.911, -19.793, -32.381) are 0.0000 Ångströms apart
# Atoms C at (-18.847, -20.439, -31.629) and C at (-18.772, -20.339, -31.636) are 0.1252 Ångströms apart
# Atoms H at (-20.153, -18.828, -32.204) and H at (-20.214, -18.85, -32.185) are 0.0676 Ångströms apart
# Atoms N at (-19.031, -14.568, -17.295) and N at (-19.031, -14.568, -17.295) are 0.0000 Ångströms apart
# Atoms C at (-18.773, -16.0, -17.433) and C at (-18.791, -15.996, -17.445) are 0.0220 Ångströms apart
# Atoms C at (-20.025, -16.701, -17.958) and C at (-20.053, -16.664, -17.995) are 0.0593 Ångströms apart
# Atoms H at (-19.862, -14.194, -17.732) and H at (-19.86, -14.188, -17.728) are 0.0075 Ångströms apart
# Atoms H at (-18.538, -16.405, -16.449) and H at (-18.578, -16.416, -16.462) are 0.0435 Ångströms apart
# Atoms N at (-46.481, -24.47, 0.495) and N at (-46.481, -24.47, 0.495) are 0.0000 Ångströms apart
# Atoms C at (-46.774, -25.194, -0.723) and C at (-46.784, -25.196, -0.721) are 0.0104 Ångströms apart
# Atoms C at (-48.28, -25.422, -0.918) and C at (-48.294, -25.397, -0.906) are 0.0311 Ångströms apart
# Atoms H at (-47.237, -24.094, 1.049) and H at (-47.234, -24.09, 1.05) are 0.0051 Ångströms apart
# Atoms H at (-46.295, -26.171, -0.654) and H at (-46.318, -26.179, -0.653) are 0.0244 Ångströms apart
# Atoms H at (-48.778, -24.453, -0.955) and H at (-48.791, -24.433, -0.799) are 0.1578 Ångströms apart
# Atoms N at (-36.712, -29.297, -12.263) and N at (-36.712, -29.297, -12.263) are 0.0000 Ångströms apart
# Atoms C at (-37.145, -29.921, -13.526) and C at (-37.137, -29.945, -13.514) are 0.0280 Ångströms apart
# Atoms C at (-38.664, -29.885, -13.697) and C at (-38.674, -30.031, -13.656) are 0.1520 Ångströms apart
# Atoms H at (-37.392, -28.847, -11.667) and H at (-37.392, -28.833, -11.678) are 0.0178 Ångströms apart
# Atoms H at (-36.843, -30.968, -13.496) and H at (-36.769, -30.97, -13.476) are 0.0767 Ångströms apart
# Atoms N at (-10.39, -28.681, 6.982) and N at (-10.39, -28.681, 6.982) are 0.0000 Ångströms apart
# Atoms C at (-10.573, -29.598, 5.863) and C at (-10.56, -29.596, 5.852) are 0.0171 Ångströms apart
# Atoms C at (-9.725, -29.119, 4.688) and C at (-9.688, -29.092, 4.697) are 0.0467 Ångströms apart
# Atoms N at (-8.961, -30.666, -0.87) and N at (-8.942, -30.518, -0.815) are 0.1590 Ångströms apart
# Atoms H at (-9.659, -27.987, 6.914) and H at (-9.662, -27.984, 6.918) are 0.0058 Ångströms apart
# Atoms H at (-11.624, -29.626, 5.575) and H at (-11.606, -29.619, 5.546) are 0.0348 Ångströms apart
# Atoms H at (-9.896, -28.052, 4.548) and H at (-10.027, -28.09, 4.435) are 0.1771 Ångströms apart
# Atoms H at (-8.673, -29.281, 4.923) and H at (-8.658, -29.026, 5.048) are 0.2844 Ångströms apart
# Atoms N at (4.6, -16.628, 7.806) and N at (4.6, -16.628, 7.806) are 0.0000 Ångströms apart
# Atoms C at (3.553, -16.075, 8.597) and C at (3.548, -16.16, 8.656) are 0.1036 Ångströms apart
# Atoms H at (5.433, -16.954, 8.275) and H at (5.465, -16.898, 8.251) are 0.0688 Ångströms apart
# Atoms H at (3.074, -15.324, 7.968) and H at (2.892, -15.526, 8.059) are 0.2867 Ångströms apart
# Atoms N at (4.398, 4.006, -8.554) and N at (4.398, 4.006, -8.554) are 0.0000 Ångströms apart
# Atoms C at (5.093, 4.527, -7.401) and C at (5.135, 4.516, -7.402) are 0.0434 Ångströms apart
# Atoms C at (4.079, 5.227, -6.525) and C at (4.237, 5.304, -6.469) are 0.1845 Ångströms apart
# Atoms H at (3.73, 3.259, -8.427) and H at (3.712, 3.278, -8.418) are 0.0277 Ångströms apart
# Atoms H at (5.85, 5.241, -7.724) and H at (5.927, 5.174, -7.76) are 0.1082 Ångströms apart
# Atoms N at (13.038, -27.236, -17.298) and N at (13.038, -27.236, -17.298) are 0.0000 Ångströms apart
# Atoms C at (12.41, -28.061, -16.267) and C at (12.428, -28.056, -16.247) are 0.0274 Ångströms apart
# Atoms C at (11.045, -28.571, -16.759) and C at (11.043, -28.563, -16.653) are 0.1063 Ångströms apart
# Atoms H at (12.783, -27.383, -18.264) and H at (12.773, -27.385, -18.261) are 0.0106 Ångströms apart
# Atoms H at (12.259, -27.454, -15.374) and H at (12.321, -27.444, -15.352) are 0.0665 Ångströms apart
# Atoms H at (11.205, -29.221, -17.619) and H at (11.142, -29.203, -17.53) are 0.1105 Ångströms apart
# Atoms N at (33.855, 5.901, -11.85) and N at (33.855, 5.901, -11.85) are 0.0000 Ångströms apart
# Atoms C at (35.181, 5.475, -11.429) and C at (35.198, 5.486, -11.479) are 0.0539 Ångströms apart
# Atoms C at (35.922, 4.795, -12.581) and C at (35.918, 4.978, -12.725) are 0.2329 Ångströms apart
# Atoms H at (33.546, 5.678, -12.785) and H at (33.524, 5.663, -12.774) are 0.0288 Ångströms apart
# Atoms H at (35.06, 4.743, -10.63) and H at (35.133, 4.678, -10.75) are 0.1548 Ångströms apart
# Atoms N at (25.841, 4.359, -5.554) and N at (25.836, 4.295, -5.518) are 0.0736 Ångströms apart
# Atoms C at (24.394, 4.549, -5.505) and C at (24.406, 4.503, -5.43) are 0.0888 Ångströms apart
# Atoms C at (23.735, 3.292, -6.061) and C at (23.725, 3.302, -6.068) are 0.0158 Ångströms apart
# Atoms O at (24.381, 2.552, -6.818) and O at (24.358, 2.597, -6.864) are 0.0683 Ångströms apart
# Atoms C at (23.962, 5.72, -6.404) and C at (24.024, 5.783, -6.172) are 0.2483 Ångströms apart
# Atoms H at (26.241, 3.967, -6.395) and H at (26.215, 3.848, -6.341) are 0.1332 Ångströms apart
# Atoms H at (24.071, 4.722, -4.479) and H at (24.109, 4.582, -4.384) are 0.1734 Ångströms apart
# Atoms H at (24.263, 5.652, -7.227) and H at (24.447, 5.597, -7.373) are 0.2412 Ångströms apart
# Atoms N at (35.809, -20.659, -7.682) and N at (35.809, -20.659, -7.682) are 0.0000 Ångströms apart
# Atoms C at (36.076, -19.337, -7.098) and C at (36.024, -19.288, -7.195) are 0.1205 Ångströms apart
# Atoms H at (35.145, -20.759, -8.437) and H at (35.135, -20.801, -8.421) are 0.0460 Ångströms apart
# Atoms H at (37.419, -19.611, -9.445) and H at (37.361, -19.504, -9.536) are 0.1520 Ångströms apart
# Atoms N at (24.724, -26.948, -23.423) and N at (24.724, -26.948, -23.423) are 0.0000 Ångströms apart
# Atoms C at (25.266, -25.685, -23.958) and C at (25.19, -25.641, -23.897) are 0.1069 Ångströms apart
# Atoms H at (25.304, -27.774, -23.461) and H at (25.319, -27.76, -23.498) are 0.0423 Ångströms apart
# Atoms H at (25.179, -24.911, -23.196) and H at (24.936, -24.898, -23.141) are 0.2495 Ångströms apart
# Atoms N at (5.608, -31.862, -28.746) and N at (5.608, -31.862, -28.746) are 0.0000 Ångströms apart
# Atoms C at (4.197, -31.702, -28.418) and C at (4.201, -31.669, -28.4) are 0.0378 Ångströms apart
# Atoms C at (3.944, -31.639, -26.889) and C at (4.017, -31.419, -26.904) are 0.2323 Ångströms apart
# Atoms H at (6.203, -31.049, -28.812) and H at (6.21, -31.055, -28.826) are 0.0168 Ångströms apart
# Atoms H at (3.688, -32.594, -28.783) and H at (3.658, -32.577, -28.663) are 0.1249 Ångströms apart
# Atoms N at (14.216, -26.339, -23.985) and N at (14.216, -26.339, -23.985) are 0.0000 Ångströms apart
# Atoms C at (13.115, -26.385, -24.942) and C at (13.084, -26.355, -24.918) are 0.0494 Ångströms apart
# Atoms C at (11.754, -26.322, -24.229) and C at (11.751, -26.141, -24.183) are 0.1868 Ångströms apart
# Atoms H at (14.376, -25.501, -23.445) and H at (14.398, -25.501, -23.452) are 0.0231 Ångströms apart
# ...
# Atoms H at (-0.618, -10.084, -59.731) and H at (-0.626, -10.088, -59.741) are 0.0134 Ångströms apart
# Atoms H at (-2.745, -8.179, -58.791) and H at (-2.729, -8.185, -58.772) are 0.0256 Ångströms apart
# Atoms H at (0.064, -7.686, -59.854) and H at (-0.036, -7.523, -60.027) are 0.2579 Ångströms apart
# Atoms N at (-11.939, 1.108, -52.227) and N at (-11.939, 1.108, -52.227) are 0.0000 Ångströms apart
# Atoms C at (-10.929, 2.163, -52.292) and C at (-10.925, 2.146, -52.328) are 0.0400 Ångströms apart
# Atoms C at (-9.781, 1.764, -53.235) and C at (-9.869, 1.706, -53.345) are 0.1523 Ångströms apart
# Atoms H at (-12.66, 1.071, -52.933) and H at (-12.676, 1.078, -52.916) are 0.0244 Ångströms apart
# Atoms H at (-10.517, 2.303, -51.293) and H at (-10.448, 2.268, -51.356) are 0.0998 Ångströms apart
# Atoms H at (-10.202, 1.286, -54.12) and H at (-10.369, 1.29, -54.219) are 0.1942 Ångströms apart
# Atoms N at (-13.163, 5.391, -26.175) and N at (-13.163, 5.391, -26.175) are 0.0000 Ångströms apart
# Atoms C at (-14.032, 6.45, -26.675) and C at (-14.064, 6.43, -26.705) are 0.0482 Ångströms apart
# Atoms C at (-13.241, 7.756, -26.695) and C at (-13.374, 7.767, -26.832) are 0.1913 Ångströms apart
# Atoms H at (-12.38, 5.103, -26.744) and H at (-12.361, 5.125, -26.728) are 0.0332 Ångströms apart
# Atoms H at (-14.891, 6.557, -26.013) and H at (-14.931, 6.528, -26.052) are 0.0629 Ångströms apart
# Atoms H at (-12.537, 7.7, -27.525) and H at (-12.399, 7.615, -27.296) are 0.2806 Ångströms apart
# Atoms N at (-20.107, 14.539, -42.015) and N at (-20.107, 14.539, -42.015) are 0.0000 Ångströms apart
# Atoms C at (-20.185, 15.754, -42.807) and C at (-20.128, 15.746, -42.832) are 0.0628 Ångströms apart
# Atoms C at (-18.801, 16.322, -43.106) and C at (-18.702, 16.172, -43.191) are 0.1988 Ångströms apart
# Atoms H at (-20.059, 13.643, -42.479) and H at (-20.099, 13.638, -42.471) are 0.0411 Ångströms apart
# Atoms H at (-20.729, 16.496, -42.223) and H at (-20.591, 16.545, -42.254) are 0.1497 Ångströms apart
# Atoms H at (-18.142, 16.154, -42.254) and H at (-18.125, 16.296, -42.274) are 0.1444 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/4GOY/4GOY/4GOY.xyz
# Atoms N at (-54.613, -20.744, 33.145) and N at (-54.613, -20.744, 33.145) are 0.0000 Ångströms apart
# Atoms C at (-54.195, -22.104, 32.811) and C at (-54.204, -22.099, 32.828) are 0.0199 Ångströms apart
# Atoms C at (-53.423, -22.749, 33.97) and C at (-53.492, -22.697, 34.032) are 0.1063 Ångströms apart
# Atoms H at (-54.74, -20.493, 34.115) and H at (-54.737, -20.487, 34.114) are 0.0068 Ångströms apart
# Atoms H at (-53.535, -22.056, 31.945) and H at (-53.51, -22.069, 31.988) are 0.0514 Ångströms apart
# Atoms H at (-54.076, -22.772, 34.842) and H at (-54.237, -22.99, 34.772) are 0.2799 Ångströms apart
# Atoms N at (-10.729, -38.678, 14.004) and N at (-10.729, -38.678, 14.004) are 0.0000 Ångströms apart
# Atoms C at (-11.158, -40.067, 13.868) and C at (-11.115, -40.079, 13.879) are 0.0460 Ångströms apart
# Atoms C at (-10.094, -40.894, 13.121) and C at (-9.952, -40.866, 13.263) are 0.2028 Ångströms apart
# Atoms H at (-9.749, -38.458, 13.894) and H at (-9.754, -38.443, 13.883) are 0.0193 Ångströms apart
# Atoms H at (-12.088, -40.094, 13.3) and H at (-11.997, -40.165, 13.245) are 0.1279 Ångströms apart
# Atoms N at (-11.412, -53.023, 9.412) and N at (-11.412, -53.023, 9.412) are 0.0000 Ångströms apart
# Atoms C at (-10.835, -52.013, 10.285) and C at (-10.83, -52.008, 10.288) are 0.0077 Ångströms apart
# Atoms C at (-11.53, -52.061, 11.644) and C at (-11.52, -52.007, 11.66) are 0.0572 Ångströms apart
# Atoms H at (-11.332, -53.998, 9.662) and H at (-11.333, -53.998, 9.663) are 0.0014 Ångströms apart
# Atoms H at (-11.017, -51.034, 9.842) and H at (-11.0, -51.034, 9.829) are 0.0214 Ångströms apart
# Atoms H at (-12.607, -52.065, 11.479) and H at (-12.598, -52.033, 11.503) are 0.0410 Ångströms apart
# Atoms N at (-32.489, -31.433, 19.894) and N at (-32.489, -31.433, 19.894) are 0.0000 Ångströms apart
# Atoms C at (-33.711, -31.563, 20.663) and C at (-33.698, -31.514, 20.702) are 0.0640 Ångströms apart
# Atoms C at (-33.435, -31.378, 22.158) and C at (-33.391, -31.095, 22.14) are 0.2870 Ångströms apart
# Atoms H at (-31.741, -30.853, 20.246) and H at (-31.725, -30.867, 20.234) are 0.0244 Ångströms apart
# Atoms H at (-34.107, -32.567, 20.509) and H at (-34.085, -32.533, 20.688) are 0.1835 Ångströms apart
# /Users/ntw/Desktop/MHT_Calculations/2VR4/2VR4/2VR4.xyz
# Atoms N at (27.448, 47.72, 40.028) and N at (27.448, 47.72, 40.028) are 0.0000 Ångströms apart
# Atoms C at (27.512, 49.179, 39.929) and C at (27.492, 49.176, 39.913) are 0.0258 Ångströms apart
# Atoms C at (28.661, 49.723, 40.8) and C at (28.612, 49.774, 40.765) are 0.0789 Ångströms apart
# Atoms H at (28.313, 47.2, 39.987) and H at (28.317, 47.206, 40.0) are 0.0149 Ångströms apart
# Atoms H at (26.572, 49.596, 40.289) and H at (26.54, 49.581, 40.255) are 0.0490 Ångströms apart
# Atoms N at (40.771, 56.046, 34.637) and N at (40.871, 56.184, 34.731) are 0.1946 Ångströms apart
# Atoms C at (41.318, 56.931, 33.633) and C at (41.237, 57.043, 33.62) are 0.1388 Ångströms apart
# Atoms C at (41.652, 56.263, 32.268) and C at (41.409, 56.171, 32.363) are 0.2767 Ångströms apart
# Atoms H at (40.576, 57.706, 33.443) and H at (40.42, 57.742, 33.443) are 0.1601 Ångströms apart
# Atoms N at (40.964, 56.677, 31.209) and N at (40.964, 56.677, 31.209) are 0.0000 Ångströms apart
# Atoms H at (40.344, 57.471, 31.279) and H at (40.507, 57.578, 31.213) are 0.2058 Ångströms apart
# Atoms N at (46.624, 57.962, 13.935) and N at (46.624, 57.962, 13.935) are 0.0000 Ångströms apart
# Atoms C at (48.02, 58.136, 14.367) and C at (47.988, 58.16, 14.47) are 0.1105 Ångströms apart
# Atoms H at (45.893, 58.485, 14.395) and H at (45.876, 58.5, 14.349) are 0.0513 Ångströms apart
# Atoms H at (48.605, 58.424, 13.494) and H at (48.616, 58.615, 13.704) are 0.2841 Ångströms apart
# Atoms N at (43.464, 59.044, 1.856) and N at (43.464, 59.044, 1.856) are 0.0000 Ångströms apart
# Atoms C at (44.516, 58.596, 0.945) and C at (44.552, 58.659, 0.992) are 0.0865 Ångströms apart
# Atoms H at (43.551, 59.933, 2.328) and H at (43.518, 59.936, 2.327) are 0.0332 Ångströms apart
# Atoms H at (44.064, 58.389, -0.025) and H at (44.193, 58.568, -0.033) are 0.2208 Ångströms apart
# Atoms N at (30.57, 48.159, 33.778) and N at (30.521, 48.143, 33.758) are 0.0553 Ångströms apart
# Atoms C at (29.949, 47.641, 34.997) and C at (29.956, 47.719, 35.031) are 0.0854 Ångströms apart
# Atoms C at (31.011, 47.165, 35.983) and C at (31.052, 47.274, 35.984) are 0.1165 Ångströms apart
# Atoms O at (32.069, 46.67, 35.579) and O at (32.161, 46.917, 35.564) are 0.2640 Ångströms apart
# Atoms C at (28.983, 46.471, 34.698) and C at (28.87, 46.607, 34.901) are 0.2692 Ångströms apart
# Atoms H at (31.244, 47.579, 33.299) and H at (31.1, 47.501, 33.236) are 0.1755 Ångströms apart
# Atoms H at (29.381, 48.446, 35.464) and H at (29.475, 48.59, 35.477) are 0.1725 Ångströms apart
# Atoms N at (30.737, 47.353, 37.269) and N at (30.737, 47.353, 37.269) are 0.0000 Ångströms apart
# Atoms H at (29.903, 47.859, 37.53) and H at (29.861, 47.78, 37.534) are 0.0896 Ångströms apart
# Atoms N at (35.995, 30.667, 39.719) and N at (35.983, 30.643, 39.705) are 0.0303 Ångströms apart
# Atoms C at (35.96, 30.722, 41.191) and C at (36.064, 30.77, 41.166) are 0.1172 Ångströms apart
# Atoms C at (37.189, 31.498, 41.716) and C at (37.243, 31.634, 41.592) are 0.1918 Ångströms apart
# Atoms H at (36.527, 29.935, 39.271) and H at (36.418, 29.851, 39.254) are 0.1387 Ångströms apart
# Atoms H at (35.065, 31.271, 41.485) and H at (35.156, 31.273, 41.499) are 0.0921 Ångströms apart
# Atoms H at (36.787, 28.778, 41.576) and H at (36.902, 28.812, 41.404) are 0.2097 Ångströms apart
# Atoms N at (36.936, 32.597, 42.447) and N at (36.936, 32.597, 42.447) are 0.0000 Ångströms apart
# Atoms H at (35.988, 32.723, 42.771) and H at (36.011, 32.621, 42.853) are 0.1329 Ångströms apart
# Atoms N at (11.795, 27.257, 32.231) and N at (11.795, 27.257, 32.231) are 0.0000 Ångströms apart
# Atoms C at (10.431, 27.711, 32.379) and C at (10.441, 27.747, 32.391) are 0.0392 Ångströms apart
# Atoms C at (10.291, 28.7, 33.542) and C at (10.402, 28.839, 33.45) are 0.2003 Ångströms apart
# Atoms O at (10.661, 28.307, 34.737) and H at (10.668, 28.228, 34.449) are 0.2987 Ångströms apart
# Atoms H at (12.477, 27.863, 31.799) and H at (12.48, 27.849, 31.783) are 0.0215 Ångströms apart
# Atoms H at (9.826, 26.838, 32.624) and H at (9.811, 26.921, 32.722) are 0.1293 Ångströms apart
# Atoms N at (6.768, 31.109, 30.217) and N at (6.735, 31.111, 30.216) are 0.0331 Ångströms apart
# Atoms C at (5.773, 32.072, 30.673) and C at (5.742, 32.08, 30.724) are 0.0602 Ångströms apart
# Atoms C at (5.627, 32.004, 32.199) and C at (5.635, 32.101, 32.238) are 0.1049 Ångströms apart
# Atoms O at (4.506, 32.012, 32.709) and O at (4.548, 32.283, 32.788) are 0.2854 Ångströms apart
# Atoms C at (4.431, 31.744, 29.995) and C at (4.363, 31.765, 30.142) are 0.1633 Ångströms apart
# Atoms H at (7.5, 31.426, 29.598) and H at (7.433, 31.434, 29.561) are 0.0770 Ångströms apart
# Atoms H at (6.086, 33.076, 30.386) and H at (6.034, 33.075, 30.389) are 0.0521 Ångströms apart
# Atoms N at (6.756, 31.866, 32.911) and N at (6.756, 31.866, 32.911) are 0.0000 Ångströms apart
# Atoms H at (7.628, 31.754, 32.414) and H at (7.608, 31.68, 32.402) are 0.0776 Ångströms apart
# Atoms N at (9.183, 29.299, 15.837) and N at (9.183, 29.299, 15.837) are 0.0000 Ångströms apart
# Atoms C at (8.97, 29.395, 14.397) and C at (8.835, 29.413, 14.408) are 0.1366 Ångströms apart
# Atoms H at (8.624, 29.848, 16.474) and H at (8.681, 29.874, 16.498) are 0.0671 Ångströms apart
# Atoms N at (4.5, 31.026, 16.005) and N at (4.396, 31.094, 16.039) are 0.1288 Ångströms apart
# Atoms C at (4.931, 31.783, 17.172) and C at (4.924, 31.85, 17.176) are 0.0675 Ångströms apart
# Atoms C at (6.425, 31.597, 17.493) and C at (6.43, 31.653, 17.339) are 0.1639 Ångströms apart
# Atoms C at (4.001, 31.458, 18.362) and C at (4.19, 31.492, 18.495) are 0.2336 Ångströms apart
# Atoms H at (4.239, 30.057, 16.118) and H at (3.987, 30.185, 16.201) are 0.2946 Ångströms apart
# Atoms H at (4.787, 32.837, 16.936) and H at (4.749, 32.908, 16.978) are 0.0908 Ångströms apart
# Atoms N at (22.963, 30.466, 49.784) and N at (22.963, 30.466, 49.784) are 0.0000 Ångströms apart
# Atoms C at (23.017, 31.621, 48.887) and C at (22.902, 31.591, 48.864) are 0.1211 Ångströms apart
# Atoms C at (24.711, 32.352, 50.726) and C at (24.72, 32.474, 50.453) are 0.2992 Ångströms apart
# Atoms H at (23.836, 30.065, 50.094) and H at (23.856, 30.108, 50.093) are 0.0474 Ångströms apart
# Atoms N at (20.813, 33.758, 32.859) and N at (20.813, 33.758, 32.859) are 0.0000 Ångströms apart
# Atoms C at (19.703, 33.194, 32.091) and C at (19.657, 33.253, 32.108) are 0.0767 Ångströms apart
# Atoms C at (18.353, 33.672, 32.631) and C at (18.363, 33.922, 32.598) are 0.2524 Ångströms apart
# Atoms O at (18.314, 35.075, 32.734) and H at (18.569, 34.97, 32.817) are 0.2880 Ångströms apart
# Atoms H at (21.006, 34.748, 32.798) and H at (21.043, 34.738, 32.782) are 0.0415 Ångströms apart
# Atoms H at (19.742, 32.108, 32.181) and H at (19.58, 32.175, 32.249) are 0.1880 Ångströms apart
# Atoms N at (16.523, 25.442, 5.828) and N at (16.523, 25.442, 5.828) are 0.0000 Ångströms apart
# Atoms C at (15.469, 24.53, 6.242) and C at (15.486, 24.501, 6.245) are 0.0337 Ångströms apart
# Atoms C at (15.938, 23.094, 6.014) and C at (16.023, 23.072, 6.066) are 0.1020 Ångströms apart
# Atoms H at (17.462, 25.304, 6.175) and H at (17.462, 25.319, 6.18) are 0.0158 Ångströms apart
# Atoms H at (14.562, 24.722, 5.668) and H at (14.581, 24.645, 5.655) are 0.0804 Ångströms apart
# Atoms H at (14.197, 21.887, 6.123) and H at (14.383, 21.705, 6.077) are 0.2643 Ångströms apart
# Atoms N at (40.381, 44.458, -10.076) and N at (40.363, 44.507, -10.136) are 0.0795 Ångströms apart
# Atoms C at (40.748, 43.046, -10.099) and C at (40.927, 43.185, -10.055) are 0.2309 Ångströms apart
# Atoms O at (42.875, 44.557, -9.943) and H at (42.757, 44.488, -9.681) are 0.2955 Ångströms apart
# Atoms H at (41.014, 45.119, -10.503) and H at (40.852, 45.177, -10.712) are 0.2707 Ångströms apart
# Atoms H at (41.077, 42.776, -11.102) and H at (40.978, 42.721, -11.04) are 0.1291 Ångströms apart
# Atoms N at (46.305, 42.367, -9.127) and N at (46.305, 42.367, -9.127) are 0.0000 Ångströms apart
# Atoms N at (37.445, 27.231, 11.596) and N at (37.445, 27.231, 11.596) are 0.0000 Ångströms apart
# Atoms C at (37.871, 26.446, 12.797) and C at (37.834, 26.416, 12.783) are 0.0496 Ångströms apart
# Atoms C at (39.396, 26.459, 12.974) and C at (39.358, 26.24, 12.922) are 0.2283 Ångströms apart
# Atoms O at (40.007, 27.467, 13.166) and H at (39.73, 27.484, 13.136) are 0.2791 Ångströms apart
# Atoms H at (38.139, 27.733, 11.061) and H at (38.146, 27.744, 11.08) are 0.0230 Ångströms apart
# Atoms H at (37.562, 25.412, 12.646) and H at (37.419, 25.42, 12.626) are 0.1446 Ångströms apart
# Atoms N at (28.929, 36.976, -14.825) and N at (28.929, 36.976, -14.825) are 0.0000 Ångströms apart
# Atoms C at (29.271, 35.642, -15.328) and C at (29.27, 35.653, -15.337) are 0.0142 Ångströms apart
# Atoms C at (30.466, 35.057, -14.567) and C at (30.519, 35.121, -14.626) are 0.1019 Ångströms apart
# Atoms H at (28.56, 37.06, -13.889) and H at (28.562, 37.056, -13.887) are 0.0049 Ångströms apart
# Atoms H at (29.536, 35.725, -16.382) and H at (29.502, 35.751, -16.398) are 0.0457 Ångströms apart
# Atoms H at (30.318, 35.257, -13.506) and H at (30.317, 35.078, -13.556) are 0.1859 Ångströms apart
# Atoms N at (18.992, 68.172, 6.175) and N at (19.154, 68.202, 6.287) are 0.1992 Ångströms apart
# Atoms C at (20.016, 70.496, 2.438) and C at (19.902, 70.654, 2.334) are 0.2209 Ångströms apart
# Atoms C at (20.186, 66.506, -8.473) and C at (20.186, 66.506, -8.473) are 0.0000 Ångströms apart
# Atoms C at (18.053, 65.667, -9.836) and C at (18.259, 65.595, -9.915) are 0.2321 Ångströms apart
# Atoms C at (23.905, 68.76, -7.694) and N at (23.978, 68.662, -7.755) are 0.1366 Ångströms apart
# Atoms C at (24.42, 69.975, -6.938) and C at (24.515, 69.836, -7.083) are 0.2222 Ångströms apart
# Atoms O at (27.639, 68.113, -3.439) and H at (27.889, 68.062, -3.426) are 0.2555 Ångströms apart
# Atoms C at (20.8, 66.688, -4.243) and H at (20.868, 66.864, -4.026) are 0.2876 Ångströms apart
# Atoms H at (19.728, 68.617, -2.785) and H at (19.743, 68.814, -2.876) are 0.2175 Ångströms apart
# Atoms N at (24.757, 66.179, 3.082) and N at (24.855, 66.109, 2.928) are 0.1955 Ångströms apart
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 16
#      14                 print("Skipping " + subdir_path)
#      15                 pass
# ---> 16 traverse_check_distance("/Users/ntw/Desktop/MHT_Calculations/")
#
# Cell In[21], line 12, in traverse_check_distance(root_dir)
#      10 try:
#      11     print(subdir_path+"/"+os.path.basename(subdirname)+"/"+os.path.basename(subdirname)+".xyz")
# ---> 12     check_atoms_closer_than_threshold(subdir_path+"/"+os.path.basename(subdirname)+"/"+os.path.basename(subdirname)+".xyz")
#      13 except Exception as e:
#      14     print("Skipping " + subdir_path)
#
# Cell In[3], line 26, in check_atoms_closer_than_threshold(file_path, threshold)
#      24 for i in range(len(atoms)):
#      25     for j in range(i + 1, len(atoms)):
# ---> 26         distance = calculate_distance(atoms[i][1:], atoms[j][1:])
#      27         if distance < threshold:
#      28             print(f"Atoms {atoms[i][0]} at {atoms[i][1:]} and {atoms[j][0]} at {atoms[j][1:]} are {distance:.4f} Ångströms apart")
#
# Cell In[3], line 4, in calculate_distance(atom1, atom2)
#       1 import math
#       3 # Function to calculate the Euclidean distance between two points in 3D space
# ----> 4 def calculate_distance(atom1, atom2):
#       5     return math.sqrt((atom1[0] - atom2[0]) ** 2 + (atom1[1] - atom2[1]) ** 2 + (atom1[2] - atom2[2]) ** 2)
#       7 # Function to read .xyz file and check for atoms closer than 0.3 Ångströms
#
# KeyboardInterrupt:
